# %%
import pandas as pd
import numpy as np

from glob import glob

# %%
species = "e_coli_test_set"
isolate_prefix = "ecol-"

# %%
prediction_files = glob("../results/predictions/*" + isolate_prefix + "*.csv")

# %%
# metrics using all input sequences

for prediction_file in prediction_files:

    if "metrics" in prediction_file:
        continue

    prediction_df = pd.read_csv(prediction_file, index_col=0)

    isolate = "_".join(prediction_file.split("\\")[-1].split("_")[0:-4])

    minimap2_df = pd.read_csv(
        "../data/alignment_files/"
        + species
        + "/"
        + isolate
        + "_alignment_labelled_ambiguity_cutoff_1.csv",
        index_col=0,
    )

    tp = 0
    fp = 0
    tn = 0
    fn = 0

    for contig_name, row in prediction_df.iterrows():
        try:  # not all sequences in the graph file are also in the assembly fasta, leading to key error
            # if minimap2_df.loc[contig_name,"short_read_contig_length"] <= 1000:
            #    continue
            # if minimap2_df.loc[contig_name,"label"] == "ambiguous":
            #    continue
            if (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tp += 1
            elif (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fp += 1
            elif not (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fn += 1
            elif not (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tn += 1
        except KeyError:
            pass

    print(tp, fp, tn, fn)

    try:
        recall = tp / (tp + fn)  # TP / P = TP / (TP + FN)
    except ZeroDivisionError:
        recall = np.nan
    specificity = tn / (tn + fp)  # TN / N = TN / (TN + FP)
    try:
        precision = tp / (tp + fp)  # TP / (TP + FP)
    except ZeroDivisionError:
        precision = np.nan
    accuracy = (tp + tn) / (
        tp + tn + fp + fn
    )  # T / all = (TP + TN) / (TP + TN + FP + FN)
    try:
        f1_score = 2 * (
            (recall * precision) / (recall + precision)
        )  # harmonic mean of precision and recall
    except ZeroDivisionError:
        f1_score = np.nan

    print("isolate:", isolate)
    print("recall:", recall)
    print("specificity:", specificity)
    print("precision:", precision)
    print("accuracy:", accuracy)
    print("f1_score:", f1_score)

    result_df = pd.DataFrame(
        [[isolate, recall, specificity, precision, accuracy, f1_score, tp, fp, fn, tn]],
        columns=[
            "isolate",
            "recall",
            "specificity",
            "precision",
            "accuracy",
            "f1_score",
            "tp",
            "fp",
            "fn",
            "tn",
        ],
    )

    result_df.to_csv(
        prediction_file[:-4] + "_metrics_all_ambiguous_equal_plasmid.csv", index=False
    )
# Out:
# 20 17 101 1
# isolate: ecol-SAMN15147962
# recall: 0.9523809523809523
# specificity: 0.8559322033898306
# precision: 0.5405405405405406
# accuracy: 0.8705035971223022
# f1_score: 0.6896551724137931
# 5 11 100 13
# isolate: ecol-SAMN15147963
# recall: 0.2777777777777778
# specificity: 0.9009009009009009
# precision: 0.3125
# accuracy: 0.813953488372093
# f1_score: 0.29411764705882354
# 119 102 170 8
# isolate: ecol-SAMN15147970
# recall: 0.937007874015748
# specificity: 0.625
# precision: 0.5384615384615384
# accuracy: 0.7243107769423559
# f1_score: 0.6839080459770115
# 34 17 133 5
# isolate: ecol-SAMN15147972
# recall: 0.8717948717948718
# specificity: 0.8866666666666667
# precision: 0.6666666666666666
# accuracy: 0.8835978835978836
# f1_score: 0.7555555555555555
# 17 39 120 0
# isolate: ecol-SAMN15147977
# recall: 1.0
# specificity: 0.7547169811320755
# precision: 0.30357142857142855
# accuracy: 0.7784090909090909
# f1_score: 0.4657534246575342
# 31 22 86 9
# isolate: ecol-SAMN15147983
# recall: 0.775
# specificity: 0.7962962962962963
# precision: 0.5849056603773585
# accuracy: 0.7905405405405406
# f1_score: 0.6666666666666666
# 0 10 84 3
# isolate: ecol-SAMN15147990
# recall: 0.0
# specificity: 0.8936170212765957
# precision: 0.0
# accuracy: 0.865979381443299
# f1_score: nan
# 3 10 86 0
# isolate: ecol-SAMN15147997
# recall: 1.0
# specificity: 0.8958333333333334
# precision: 0.23076923076923078
# accuracy: 0.898989898989899
# f1_score: 0.375
# 7 37 96 4
# isolate: ecol-SAMN15148005
# recall: 0.6363636363636364
# specificity: 0.7218045112781954
# precision: 0.1590909090909091
# accuracy: 0.7152777777777778
# f1_score: 0.2545454545454546
# 0 33 160 0
# isolate: ecol-SAMN15148009
# recall: nan
# specificity: 0.8290155440414507
# precision: 0.0
# accuracy: 0.8290155440414507
# f1_score: nan
# 20 16 105 28
# isolate: ecol-SAMN15148016
# recall: 0.4166666666666667
# specificity: 0.8677685950413223
# precision: 0.5555555555555556
# accuracy: 0.7396449704142012
# f1_score: 0.4761904761904762
# 26 16 106 8
# isolate: ecol-SAMN15148018
# recall: 0.7647058823529411
# specificity: 0.8688524590163934
# precision: 0.6190476190476191
# accuracy: 0.8461538461538461
# f1_score: 0.6842105263157895
# 7 56 321 0
# isolate: ecol-SAMN15148024
# recall: 1.0
# specificity: 0.8514588859416445
# precision: 0.1111111111111111
# accuracy: 0.8541666666666666
# f1_score: 0.19999999999999998
# 25 18 75 11
# isolate: ecol-SAMN15148025
# recall: 0.6944444444444444
# specificity: 0.8064516129032258
# precision: 0.5813953488372093
# accuracy: 0.7751937984496124
# f1_score: 0.6329113924050633
# 11 11 169 1
# isolate: ecol-SAMN15148037
# recall: 0.9166666666666666
# specificity: 0.9388888888888889
# precision: 0.5
# accuracy: 0.9375
# f1_score: 0.6470588235294118
# 11 14 157 0
# isolate: ecol-SAMN15148039
# recall: 1.0
# specificity: 0.9181286549707602
# precision: 0.44
# accuracy: 0.9230769230769231
# f1_score: 0.6111111111111112
# 0 13 108 0
# isolate: ecol-SAMN15148048
# recall: nan
# specificity: 0.8925619834710744
# precision: 0.0
# accuracy: 0.8925619834710744
# f1_score: nan
# 7 43 95 0
# isolate: ecol-SAMN15148049
# recall: 1.0
# specificity: 0.6884057971014492
# precision: 0.14
# accuracy: 0.7034482758620689
# f1_score: 0.24561403508771928
# 9 8 112 3
# isolate: ecol-SAMN15148053
# recall: 0.75
# specificity: 0.9333333333333333
# precision: 0.5294117647058824
# accuracy: 0.9166666666666666
# f1_score: 0.6206896551724139
# 3 13 140 6
# isolate: ecol-SAMN15148054
# recall: 0.3333333333333333
# specificity: 0.9150326797385621
# precision: 0.1875
# accuracy: 0.8827160493827161
# f1_score: 0.24000000000000005
# 22 36 231 2
# isolate: ecol-SAMN15148060
# recall: 0.9166666666666666
# specificity: 0.8651685393258427
# precision: 0.3793103448275862
# accuracy: 0.8694158075601375
# f1_score: 0.5365853658536586
# 7 24 161 3
# isolate: ecol-SAMN15148070
# recall: 0.7
# specificity: 0.8702702702702703
# precision: 0.22580645161290322
# accuracy: 0.8615384615384616
# f1_score: 0.3414634146341463
# 2 7 128 1
# isolate: ecol-SAMN15148072
# recall: 0.6666666666666666
# specificity: 0.9481481481481482
# precision: 0.2222222222222222
# accuracy: 0.9420289855072463
# f1_score: 0.3333333333333333
# 10 10 140 13
# isolate: ecol-SAMN15148083
# recall: 0.43478260869565216
# specificity: 0.9333333333333333
# precision: 0.5
# accuracy: 0.8670520231213873
# f1_score: 0.46511627906976744
# 17 14 246 25
# isolate: ecol-SAMN15148089
# recall: 0.40476190476190477
# specificity: 0.9461538461538461
# precision: 0.5483870967741935
# accuracy: 0.8708609271523179
# f1_score: 0.4657534246575342
# 13 14 245 28
# isolate: ecol-SAMN15148090
# recall: 0.3170731707317073
# specificity: 0.9459459459459459
# precision: 0.48148148148148145
# accuracy: 0.86
# f1_score: 0.3823529411764706
# 15 12 191 23
# isolate: ecol-SAMN15148091
# recall: 0.39473684210526316
# specificity: 0.9408866995073891
# precision: 0.5555555555555556
# accuracy: 0.8547717842323651
# f1_score: 0.46153846153846156
# 2 8 43 3
# isolate: ecol-SAMN15148093
# recall: 0.4
# specificity: 0.8431372549019608
# precision: 0.2
# accuracy: 0.8035714285714286
# f1_score: 0.26666666666666666
# 1 9 41 0
# isolate: ecol-SAMN15148094
# recall: 1.0
# specificity: 0.82
# precision: 0.1
# accuracy: 0.8235294117647058
# f1_score: 0.18181818181818182
# 8 14 90 0
# isolate: ecol-SAMN15148099
# recall: 1.0
# specificity: 0.8653846153846154
# precision: 0.36363636363636365
# accuracy: 0.875
# f1_score: 0.5333333333333333
# 8 22 104 3
# isolate: ecol-SAMN15148100
# recall: 0.7272727272727273
# specificity: 0.8253968253968254
# precision: 0.26666666666666666
# accuracy: 0.8175182481751825
# f1_score: 0.3902439024390244
# 8 7 55 0
# isolate: ecol-SAMN15148101
# recall: 1.0
# specificity: 0.8870967741935484
# precision: 0.5333333333333333
# accuracy: 0.9
# f1_score: 0.6956521739130436
# 12 12 59 2
# isolate: ecol-SAMN15148102
# recall: 0.8571428571428571
# specificity: 0.8309859154929577
# precision: 0.5
# accuracy: 0.8352941176470589
# f1_score: 0.631578947368421
# 49 39 110 30
# isolate: ecol-SAMN15148111
# recall: 0.620253164556962
# specificity: 0.738255033557047
# precision: 0.5568181818181818
# accuracy: 0.6973684210526315
# f1_score: 0.5868263473053892
# 30 7 64 0
# isolate: ecol-SAMN15148112
# recall: 1.0
# specificity: 0.9014084507042254
# precision: 0.8108108108108109
# accuracy: 0.9306930693069307
# f1_score: 0.8955223880597014
# 89 47 216 12
# isolate: ecol-SAMN15148118
# recall: 0.8811881188118812
# specificity: 0.8212927756653993
# precision: 0.6544117647058824
# accuracy: 0.8379120879120879
# f1_score: 0.7510548523206751
# 4 59 92 0
# isolate: ecol-SAMN15148121
# recall: 1.0
# specificity: 0.609271523178808
# precision: 0.06349206349206349
# accuracy: 0.6193548387096774
# f1_score: 0.11940298507462686
# 87 53 211 15
# isolate: ecol-SAMN15148127
# recall: 0.8529411764705882
# specificity: 0.7992424242424242
# precision: 0.6214285714285714
# accuracy: 0.8142076502732241
# f1_score: 0.7190082644628099
# 103 65 197 36
# isolate: ecol-SAMN15148136
# recall: 0.7410071942446043
# specificity: 0.7519083969465649
# precision: 0.6130952380952381
# accuracy: 0.7481296758104738
# f1_score: 0.6710097719869708
# 15 8 123 14
# isolate: ecol-SAMN15148138
# recall: 0.5172413793103449
# specificity: 0.9389312977099237
# precision: 0.6521739130434783
# accuracy: 0.8625
# f1_score: 0.576923076923077
# 24 24 100 15
# isolate: ecol-SAMN15148139
# recall: 0.6153846153846154
# specificity: 0.8064516129032258
# precision: 0.5
# accuracy: 0.7607361963190185
# f1_score: 0.5517241379310345
# 29 39 181 3
# isolate: ecol-SAMN15148143
# recall: 0.90625
# specificity: 0.8227272727272728
# precision: 0.4264705882352941
# accuracy: 0.8333333333333334
# f1_score: 0.58
# 16 30 58 14
# isolate: ecol-SAMN15148145
# recall: 0.5333333333333333
# specificity: 0.6590909090909091
# precision: 0.34782608695652173
# accuracy: 0.6271186440677966
# f1_score: 0.4210526315789474
# 5 2 59 3
# isolate: ecol-SAMN15148148
# recall: 0.625
# specificity: 0.9672131147540983
# precision: 0.7142857142857143
# accuracy: 0.927536231884058
# f1_score: 0.6666666666666666
# 1 5 86 0
# isolate: ecol-SAMN15148149
# recall: 1.0
# specificity: 0.945054945054945
# precision: 0.16666666666666666
# accuracy: 0.9456521739130435
# f1_score: 0.2857142857142857
# 39 144 272 1
# isolate: ecol-SAMN15148177
# recall: 0.975
# specificity: 0.6538461538461539
# precision: 0.21311475409836064
# accuracy: 0.6820175438596491
# f1_score: 0.34977578475336324
# 14 7 97 6
# isolate: ecol-SAMN15148207
# recall: 0.7
# specificity: 0.9326923076923077
# precision: 0.6666666666666666
# accuracy: 0.8951612903225806
# f1_score: 0.6829268292682926
# 21 7 96 1
# isolate: ecol-SAMN15148215
# recall: 0.9545454545454546
# specificity: 0.9320388349514563
# precision: 0.75
# accuracy: 0.936
# f1_score: 0.84
# 6 7 122 3
# isolate: ecol-SAMN15148217
# recall: 0.6666666666666666
# specificity: 0.9457364341085271
# precision: 0.46153846153846156
# accuracy: 0.927536231884058
# f1_score: 0.5454545454545455
# 21 17 136 0
# isolate: ecol-SAMN15148218
# recall: 1.0
# specificity: 0.8888888888888888
# precision: 0.5526315789473685
# accuracy: 0.9022988505747126
# f1_score: 0.711864406779661
# 6 15 244 12
# isolate: ecol-SAMN15148228
# recall: 0.3333333333333333
# specificity: 0.9420849420849421
# precision: 0.2857142857142857
# accuracy: 0.9025270758122743
# f1_score: 0.30769230769230765
# 10 9 76 25
# isolate: ecol-SAMN15148229
# recall: 0.2857142857142857
# specificity: 0.8941176470588236
# precision: 0.5263157894736842
# accuracy: 0.7166666666666667
# f1_score: 0.37037037037037035
# 51 167 196 0
# isolate: ecol-SAMN15148263
# recall: 1.0
# specificity: 0.5399449035812672
# precision: 0.23394495412844038
# accuracy: 0.5966183574879227
# f1_score: 0.379182156133829
# 43 31 90 0
# isolate: ecol-SAMN15148267
# recall: 1.0
# specificity: 0.743801652892562
# precision: 0.581081081081081
# accuracy: 0.8109756097560976
# f1_score: 0.735042735042735
# 2 29 130 8
# isolate: ecol-SAMN15148268
# recall: 0.2
# specificity: 0.8176100628930818
# precision: 0.06451612903225806
# accuracy: 0.7810650887573964
# f1_score: 0.0975609756097561
# 3 31 145 0
# isolate: ecol-SAMN15148273
# recall: 1.0
# specificity: 0.8238636363636364
# precision: 0.08823529411764706
# accuracy: 0.8268156424581006
# f1_score: 0.1621621621621622
# 48 37 194 8
# isolate: ecol-SAMN15148298
# recall: 0.8571428571428571
# specificity: 0.8398268398268398
# precision: 0.5647058823529412
# accuracy: 0.8432055749128919
# f1_score: 0.6808510638297872
# 3 21 94 2
# isolate: ecol-SAMN15148314
# recall: 0.6
# specificity: 0.8173913043478261
# precision: 0.125
# accuracy: 0.8083333333333333
# f1_score: 0.20689655172413793
# 40 16 81 0
# isolate: ecol-SAMN15148328
# recall: 1.0
# specificity: 0.8350515463917526
# precision: 0.7142857142857143
# accuracy: 0.8832116788321168
# f1_score: 0.8333333333333333
# 6 4 78 4
# isolate: ecol-SAMN15148331
# recall: 0.6
# specificity: 0.9512195121951219
# precision: 0.6
# accuracy: 0.9130434782608695
# f1_score: 0.6
# 4 12 50 0
# isolate: ecol-SAMN15148349
# recall: 1.0
# specificity: 0.8064516129032258
# precision: 0.25
# accuracy: 0.8181818181818182
# f1_score: 0.4
# 95 52 174 12
# isolate: ecol-SAMN15148350
# recall: 0.8878504672897196
# specificity: 0.7699115044247787
# precision: 0.6462585034013606
# accuracy: 0.8078078078078078
# f1_score: 0.7480314960629922
# 5 33 180 10
# isolate: ecol-SAMN15148351
# recall: 0.3333333333333333
# specificity: 0.8450704225352113
# precision: 0.13157894736842105
# accuracy: 0.8114035087719298
# f1_score: 0.18867924528301885
# 3 11 89 0
# isolate: ecol-SAMN15148359
# recall: 1.0
# specificity: 0.89
# precision: 0.21428571428571427
# accuracy: 0.8932038834951457
# f1_score: 0.35294117647058826
# 0 17 135 0
# isolate: ecol-SAMN15148360
# recall: nan
# specificity: 0.8881578947368421
# precision: 0.0
# accuracy: 0.8881578947368421
# f1_score: nan
# 0 39 133 2
# isolate: ecol-SAMN15148362
# recall: 0.0
# specificity: 0.7732558139534884
# precision: 0.0
# accuracy: 0.764367816091954
# f1_score: nan
# 7 14 121 6
# isolate: ecol-SAMN15148366
# recall: 0.5384615384615384
# specificity: 0.8962962962962963
# precision: 0.3333333333333333
# accuracy: 0.8648648648648649
# f1_score: 0.41176470588235287
# 5 44 205 2
# isolate: ecol-SAMN15148368
# recall: 0.7142857142857143
# specificity: 0.8232931726907631
# precision: 0.10204081632653061
# accuracy: 0.8203125
# f1_score: 0.17857142857142858
# 104 14 123 0
# isolate: ecol-SAMN15148379
# recall: 1.0
# specificity: 0.8978102189781022
# precision: 0.8813559322033898
# accuracy: 0.941908713692946
# f1_score: 0.936936936936937
# 52 83 170 0
# isolate: ecol-SAMN15148387
# recall: 1.0
# specificity: 0.6719367588932806
# precision: 0.3851851851851852
# accuracy: 0.7278688524590164
# f1_score: 0.5561497326203209
# 99 136 109 6
# isolate: ecol-SAMN15148388
# recall: 0.9428571428571428
# specificity: 0.4448979591836735
# precision: 0.42127659574468085
# accuracy: 0.5942857142857143
# f1_score: 0.5823529411764705
# 87 235 192 0
# isolate: ecol-SAMN15148391
# recall: 1.0
# specificity: 0.4496487119437939
# precision: 0.2701863354037267
# accuracy: 0.5428015564202334
# f1_score: 0.42542787286063566
# 6 19 184 1
# isolate: ecol-SAMN15148397
# recall: 0.8571428571428571
# specificity: 0.9064039408866995
# precision: 0.24
# accuracy: 0.9047619047619048
# f1_score: 0.375
# 56 30 185 0
# isolate: ecol-SAMN15148400
# recall: 1.0
# specificity: 0.8604651162790697
# precision: 0.6511627906976745
# accuracy: 0.8892988929889298
# f1_score: 0.7887323943661972
# 45 35 92 0
# isolate: ecol-SAMN15148423
# recall: 1.0
# specificity: 0.7244094488188977
# precision: 0.5625
# accuracy: 0.7965116279069767
# f1_score: 0.72
# 115 31 122 33
# isolate: ecol-SAMN15148426
# recall: 0.777027027027027
# specificity: 0.7973856209150327
# precision: 0.7876712328767124
# accuracy: 0.7873754152823921
# f1_score: 0.782312925170068
# 3 21 117 0
# isolate: ecol-SAMN15148433
# recall: 1.0
# specificity: 0.8478260869565217
# precision: 0.125
# accuracy: 0.851063829787234
# f1_score: 0.2222222222222222
# 3 18 154 0
# isolate: ecol-SAMN15148461
# recall: 1.0
# specificity: 0.8953488372093024
# precision: 0.14285714285714285
# accuracy: 0.8971428571428571
# f1_score: 0.25
# 91 16 125 11
# isolate: ecol-SAMN15148475
# recall: 0.8921568627450981
# specificity: 0.8865248226950354
# precision: 0.8504672897196262
# accuracy: 0.8888888888888888
# f1_score: 0.8708133971291867
# 74 63 125 77
# isolate: ecol-SAMN15148482
# recall: 0.4900662251655629
# specificity: 0.6648936170212766
# precision: 0.5401459854014599
# accuracy: 0.5870206489675516
# f1_score: 0.513888888888889
# 0 14 129 0
# isolate: ecol-SAMN15148483
# recall: nan
# specificity: 0.9020979020979021
# precision: 0.0
# accuracy: 0.9020979020979021
# f1_score: nan
# 60 13 160 1
# isolate: ecol-SAMN15148515
# recall: 0.9836065573770492
# specificity: 0.9248554913294798
# precision: 0.821917808219178
# accuracy: 0.9401709401709402
# f1_score: 0.8955223880597014
# 6 19 76 0
# isolate: ecol-SAMN15148547
# recall: 1.0
# specificity: 0.8
# precision: 0.24
# accuracy: 0.8118811881188119
# f1_score: 0.3870967741935484
# 13 16 123 0
# isolate: ecol-SAMN15148548
# recall: 1.0
# specificity: 0.8848920863309353
# precision: 0.4482758620689655
# accuracy: 0.8947368421052632
# f1_score: 0.6190476190476191
# 14 33 146 29
# isolate: ecol-SAMN15148563
# recall: 0.32558139534883723
# specificity: 0.8156424581005587
# precision: 0.2978723404255319
# accuracy: 0.7207207207207207
# f1_score: 0.3111111111111111
# 0 32 184 4
# isolate: ecol-SAMN15148570
# recall: 0.0
# specificity: 0.8518518518518519
# precision: 0.0
# accuracy: 0.8363636363636363
# f1_score: nan
# 58 23 123 25
# isolate: ecol-SAMN15148576
# recall: 0.6987951807228916
# specificity: 0.8424657534246576
# precision: 0.7160493827160493
# accuracy: 0.7903930131004366
# f1_score: 0.7073170731707318
# 0 54 182 0
# isolate: ecol-SAMN15148585
# recall: nan
# specificity: 0.7711864406779662
# precision: 0.0
# accuracy: 0.7711864406779662
# f1_score: nan
# 3 10 95 16
# isolate: ecol-SAMN15148591
# recall: 0.15789473684210525
# specificity: 0.9047619047619048
# precision: 0.23076923076923078
# accuracy: 0.7903225806451613
# f1_score: 0.18749999999999997
# 30 28 180 10
# isolate: ecol-SAMN15148593
# recall: 0.75
# specificity: 0.8653846153846154
# precision: 0.5172413793103449
# accuracy: 0.8467741935483871
# f1_score: 0.6122448979591838
# 98 30 158 25
# isolate: ecol-SAMN15148596
# recall: 0.7967479674796748
# specificity: 0.8404255319148937
# precision: 0.765625
# accuracy: 0.8231511254019293
# f1_score: 0.7808764940239042
# 90 36 359 0
# isolate: ecol-SAMN15148605
# recall: 1.0
# specificity: 0.9088607594936708
# precision: 0.7142857142857143
# accuracy: 0.9257731958762887
# f1_score: 0.8333333333333333
# 14 19 185 0
# isolate: ecol-SAMN15148627
# recall: 1.0
# specificity: 0.9068627450980392
# precision: 0.42424242424242425
# accuracy: 0.9128440366972477
# f1_score: 0.5957446808510638
# 65 127 102 0
# isolate: ecol-SAMN15148648
# recall: 1.0
# specificity: 0.44541484716157204
# precision: 0.3385416666666667
# accuracy: 0.5680272108843537
# f1_score: 0.5058365758754864
# 22 16 98 0
# isolate: ecol-SAMN15148701
# recall: 1.0
# specificity: 0.8596491228070176
# precision: 0.5789473684210527
# accuracy: 0.8823529411764706
# f1_score: 0.7333333333333334
# 31 17 96 7
# isolate: ecol-SAMN15148710
# recall: 0.8157894736842105
# specificity: 0.8495575221238938
# precision: 0.6458333333333334
# accuracy: 0.8410596026490066
# f1_score: 0.7209302325581395
# 1 14 88 0
# isolate: ecol-SAMN15148714
# recall: 1.0
# specificity: 0.8627450980392157
# precision: 0.06666666666666667
# accuracy: 0.8640776699029126
# f1_score: 0.125
# 1 17 112 4
# isolate: ecol-SAMN15148720
# recall: 0.2
# specificity: 0.8682170542635659
# precision: 0.05555555555555555
# accuracy: 0.8432835820895522
# f1_score: 0.08695652173913045
# 21 39 140 3
# isolate: ecol-SAMN15148732
# recall: 0.875
# specificity: 0.7821229050279329
# precision: 0.35
# accuracy: 0.7931034482758621
# f1_score: 0.4999999999999999
# 6 23 112 1
# isolate: ecol-SAMN15148739
# recall: 0.8571428571428571
# specificity: 0.8296296296296296
# precision: 0.20689655172413793
# accuracy: 0.8309859154929577
# f1_score: 0.33333333333333326
# 4 22 95 60
# isolate: ecol-SAMN21365996
# recall: 0.0625
# specificity: 0.811965811965812
# precision: 0.15384615384615385
# accuracy: 0.5469613259668509
# f1_score: 0.08888888888888889
# 15 16 145 24
# isolate: ecol-SAMN21365997
# recall: 0.38461538461538464
# specificity: 0.9006211180124224
# precision: 0.4838709677419355
# accuracy: 0.8
# f1_score: 0.4285714285714286
# 18 29 99 0
# isolate: ecol-SAMN21366003
# recall: 1.0
# specificity: 0.7734375
# precision: 0.3829787234042553
# accuracy: 0.8013698630136986
# f1_score: 0.5538461538461539
# 12 42 140 186
# isolate: ecol-SAMN21366006
# recall: 0.06060606060606061
# specificity: 0.7692307692307693
# precision: 0.2222222222222222
# accuracy: 0.4
# f1_score: 0.09523809523809523
# 51 63 138 40
# isolate: ecol-SAMN21366010
# recall: 0.5604395604395604
# specificity: 0.6865671641791045
# precision: 0.4473684210526316
# accuracy: 0.6472602739726028
# f1_score: 0.4975609756097561
# 49 70 127 13
# isolate: ecol-SAMN21366012
# recall: 0.7903225806451613
# specificity: 0.6446700507614214
# precision: 0.4117647058823529
# accuracy: 0.6795366795366795
# f1_score: 0.5414364640883977
# 28 18 101 12
# isolate: ecol-SAMN21366015
# recall: 0.7
# specificity: 0.8487394957983193
# precision: 0.6086956521739131
# accuracy: 0.8113207547169812
# f1_score: 0.6511627906976744
# 17 18 184 18
# isolate: ecol-SAMN21366016
# recall: 0.4857142857142857
# specificity: 0.9108910891089109
# precision: 0.4857142857142857
# accuracy: 0.8481012658227848
# f1_score: 0.4857142857142857
# 71 30 107 19
# isolate: ecol-SAMN21366024
# recall: 0.7888888888888889
# specificity: 0.781021897810219
# precision: 0.7029702970297029
# accuracy: 0.7841409691629956
# f1_score: 0.7434554973821988
# 20 22 44 3
# isolate: ecol-SAMN21366035
# recall: 0.8695652173913043
# specificity: 0.6666666666666666
# precision: 0.47619047619047616
# accuracy: 0.7191011235955056
# f1_score: 0.6153846153846153
# 25 51 125 18
# isolate: ecol-SAMN21366039
# recall: 0.5813953488372093
# specificity: 0.7102272727272727
# precision: 0.32894736842105265
# accuracy: 0.684931506849315
# f1_score: 0.4201680672268908
# 4 43 179 10
# isolate: ecol-SAMN21366041
# recall: 0.2857142857142857
# specificity: 0.8063063063063063
# precision: 0.0851063829787234
# accuracy: 0.7754237288135594
# f1_score: 0.13114754098360654
# 54 32 174 11
# isolate: ecol-SAMN21366042
# recall: 0.8307692307692308
# specificity: 0.8446601941747572
# precision: 0.627906976744186
# accuracy: 0.8413284132841329
# f1_score: 0.7152317880794703
# 19 28 136 7
# isolate: ecol-SAMN21366045
# recall: 0.7307692307692307
# specificity: 0.8292682926829268
# precision: 0.40425531914893614
# accuracy: 0.8157894736842105
# f1_score: 0.5205479452054794
# 16 33 148 3
# isolate: ecol-SAMN21366046
# recall: 0.8421052631578947
# specificity: 0.8176795580110497
# precision: 0.32653061224489793
# accuracy: 0.82
# f1_score: 0.4705882352941176
# 15 29 158 15
# isolate: ecol-SAMN21366053
# recall: 0.5
# specificity: 0.8449197860962567
# precision: 0.3409090909090909
# accuracy: 0.7972350230414746
# f1_score: 0.40540540540540543
# 26 31 130 26
# isolate: ecol-SAMN21366054
# recall: 0.5
# specificity: 0.8074534161490683
# precision: 0.45614035087719296
# accuracy: 0.7323943661971831
# f1_score: 0.4770642201834862
# 17 36 185 8
# isolate: ecol-SAMN21366055
# recall: 0.68
# specificity: 0.8371040723981901
# precision: 0.32075471698113206
# accuracy: 0.8211382113821138
# f1_score: 0.43589743589743585
# 8 10 98 3
# isolate: ecol-SAMN21366059
# recall: 0.7272727272727273
# specificity: 0.9074074074074074
# precision: 0.4444444444444444
# accuracy: 0.8907563025210085
# f1_score: 0.5517241379310345
# 47 19 203 34
# isolate: ecol-SAMN21366065
# recall: 0.5802469135802469
# specificity: 0.9144144144144144
# precision: 0.7121212121212122
# accuracy: 0.8250825082508251
# f1_score: 0.6394557823129252
# 29 60 126 19
# isolate: ecol-SAMN21366066
# recall: 0.6041666666666666
# specificity: 0.6774193548387096
# precision: 0.3258426966292135
# accuracy: 0.6623931623931624
# f1_score: 0.4233576642335766
# 20 19 85 28
# isolate: ecol-SAMN21366068
# recall: 0.4166666666666667
# specificity: 0.8173076923076923
# precision: 0.5128205128205128
# accuracy: 0.6907894736842105
# f1_score: 0.4597701149425287
# 120 22 137 11
# isolate: ecol-SAMN21366072
# recall: 0.916030534351145
# specificity: 0.8616352201257862
# precision: 0.8450704225352113
# accuracy: 0.8862068965517241
# f1_score: 0.8791208791208791
# 38 60 237 21
# isolate: ecol-SAMN21366074
# recall: 0.6440677966101694
# specificity: 0.797979797979798
# precision: 0.3877551020408163
# accuracy: 0.7724719101123596
# f1_score: 0.4840764331210191
# 84 74 309 70
# isolate: ecol-SAMN21366078
# recall: 0.5454545454545454
# specificity: 0.8067885117493473
# precision: 0.5316455696202531
# accuracy: 0.7318435754189944
# f1_score: 0.5384615384615384
# 61 45 308 28
# isolate: ecol-SAMN21366079
# recall: 0.6853932584269663
# specificity: 0.8725212464589235
# precision: 0.5754716981132075
# accuracy: 0.834841628959276
# f1_score: 0.6256410256410255
# 76 39 137 53
# isolate: ecol-SAMN21366080
# recall: 0.5891472868217055
# specificity: 0.7784090909090909
# precision: 0.6608695652173913
# accuracy: 0.6983606557377049
# f1_score: 0.6229508196721312
# 19 31 140 52
# isolate: ecol-SAMN21366081
# recall: 0.2676056338028169
# specificity: 0.8187134502923976
# precision: 0.38
# accuracy: 0.6570247933884298
# f1_score: 0.3140495867768595
# 26 60 111 14
# isolate: ecol-SAMN21366082
# recall: 0.65
# specificity: 0.6491228070175439
# precision: 0.3023255813953488
# accuracy: 0.6492890995260664
# f1_score: 0.4126984126984127
# 66 29 129 51
# isolate: ecol-SAMN21366083
# recall: 0.5641025641025641
# specificity: 0.8164556962025317
# precision: 0.6947368421052632
# accuracy: 0.7090909090909091
# f1_score: 0.6226415094339622
# 62 31 170 249
# isolate: ecol-SAMN21366084
# recall: 0.19935691318327975
# specificity: 0.845771144278607
# precision: 0.6666666666666666
# accuracy: 0.453125
# f1_score: 0.3069306930693069

# %%
# metrics using all input sequences

for prediction_file in prediction_files:

    if "metrics" in prediction_file:
        continue

    prediction_df = pd.read_csv(prediction_file, index_col=0)

    isolate = "_".join(prediction_file.split("\\")[-1].split("_")[0:-4])

    minimap2_df = pd.read_csv(
        "../data/alignment_files/"
        + species
        + "/"
        + isolate
        + "_alignment_labelled_ambiguity_cutoff_1.csv",
        index_col=0,
    )

    tp = 0
    fp = 0
    tn = 0
    fn = 0

    for contig_name, row in prediction_df.iterrows():
        try:  # not all sequences in the graph file are also in the assembly fasta, leading to key error
            # if minimap2_df.loc[contig_name,"short_read_contig_length"] <= 1000:
            #    continue
            # if minimap2_df.loc[contig_name,"label"] == "ambiguous":
            #    continue
            if (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tp += 1
            elif (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fp += 1
            elif not (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fn += 1
            elif not (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tn += 1
        except KeyError:
            pass

    print(tp, fp, tn, fn)

    try:
        recall = tp / (tp + fn)  # TP / P = TP / (TP + FN)
    except ZeroDivisionError:
        recall = np.nan
    try:
        specificity = tn / (tn + fp)  # TN / N = TN / (TN + FP)
    except ZeroDivisionError:
        specificity = np.nan
    try:
        precision = tp / (tp + fp)  # TP / (TP + FP)
    except ZeroDivisionError:
        precision = np.nan
    accuracy = (tp + tn) / (
        tp + tn + fp + fn
    )  # T / all = (TP + TN) / (TP + TN + FP + FN)
    try:
        f1_score = 2 * (
            (recall * precision) / (recall + precision)
        )  # harmonic mean of precision and recall
    except ZeroDivisionError:
        f1_score = np.nan

    print("isolate:", isolate)
    print("recall:", recall)
    print("specificity:", specificity)
    print("precision:", precision)
    print("accuracy:", accuracy)
    print("f1_score:", f1_score)

    result_df = pd.DataFrame(
        [[isolate, recall, specificity, precision, accuracy, f1_score, tp, fp, fn, tn]],
        columns=[
            "isolate",
            "recall",
            "specificity",
            "precision",
            "accuracy",
            "f1_score",
            "tp",
            "fp",
            "fn",
            "tn",
        ],
    )

    result_df.to_csv(
        prediction_file[:-4] + "_metrics_all_ambiguous_equal_chromosome.csv",
        index=False,
    )
# Out:
# 110 1 10 18
# isolate: ecol-SAMN15147962
# recall: 0.859375
# specificity: 0.9090909090909091
# precision: 0.990990990990991
# accuracy: 0.8633093525179856
# f1_score: 0.9205020920502092
# 114 12 1 2
# isolate: ecol-SAMN15147963
# recall: 0.9827586206896551
# specificity: 0.07692307692307693
# precision: 0.9047619047619048
# accuracy: 0.8914728682170543
# f1_score: 0.9421487603305785
# 236 23 72 68
# isolate: ecol-SAMN15147970
# recall: 0.7763157894736842
# specificity: 0.7578947368421053
# precision: 0.9111969111969112
# accuracy: 0.7719298245614035
# f1_score: 0.8383658969804618
# 152 10 18 9
# isolate: ecol-SAMN15147972
# recall: 0.9440993788819876
# specificity: 0.6428571428571429
# precision: 0.9382716049382716
# accuracy: 0.8994708994708994
# f1_score: 0.9411764705882353
# 144 7 2 23
# isolate: ecol-SAMN15147977
# recall: 0.8622754491017964
# specificity: 0.2222222222222222
# precision: 0.9536423841059603
# accuracy: 0.8295454545454546
# f1_score: 0.9056603773584905
# 109 15 16 8
# isolate: ecol-SAMN15147983
# recall: 0.9316239316239316
# specificity: 0.5161290322580645
# precision: 0.8790322580645161
# accuracy: 0.8445945945945946
# f1_score: 0.904564315352697
# 93 1 0 3
# isolate: ecol-SAMN15147990
# recall: 0.96875
# specificity: 0.0
# precision: 0.9893617021276596
# accuracy: 0.9587628865979382
# f1_score: 0.9789473684210526
# 94 0 3 2
# isolate: ecol-SAMN15147997
# recall: 0.9791666666666666
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9797979797979798
# f1_score: 0.9894736842105264
# 127 1 7 9
# isolate: ecol-SAMN15148005
# recall: 0.9338235294117647
# specificity: 0.875
# precision: 0.9921875
# accuracy: 0.9305555555555556
# f1_score: 0.9621212121212122
# 182 0 0 11
# isolate: ecol-SAMN15148009
# recall: 0.9430051813471503
# specificity: nan
# precision: 1.0
# accuracy: 0.9430051813471503
# f1_score: 0.9706666666666667
# 125 28 10 6
# isolate: ecol-SAMN15148016
# recall: 0.9541984732824428
# specificity: 0.2631578947368421
# precision: 0.8169934640522876
# accuracy: 0.7988165680473372
# f1_score: 0.8802816901408452
# 125 9 14 8
# isolate: ecol-SAMN15148018
# recall: 0.9398496240601504
# specificity: 0.6086956521739131
# precision: 0.9328358208955224
# accuracy: 0.8910256410256411
# f1_score: 0.9363295880149812
# 355 0 6 23
# isolate: ecol-SAMN15148024
# recall: 0.9391534391534392
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9401041666666666
# f1_score: 0.9686221009549796
# 93 17 16 3
# isolate: ecol-SAMN15148025
# recall: 0.96875
# specificity: 0.48484848484848486
# precision: 0.8454545454545455
# accuracy: 0.8449612403100775
# f1_score: 0.9029126213592233
# 184 0 1 7
# isolate: ecol-SAMN15148037
# recall: 0.9633507853403142
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9635416666666666
# f1_score: 0.9813333333333333
# 167 0 2 13
# isolate: ecol-SAMN15148039
# recall: 0.9277777777777778
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9285714285714286
# f1_score: 0.962536023054755
# 115 0 0 6
# isolate: ecol-SAMN15148048
# recall: 0.9504132231404959
# specificity: nan
# precision: 1.0
# accuracy: 0.9504132231404959
# f1_score: 0.9745762711864406
# 115 0 6 24
# isolate: ecol-SAMN15148049
# recall: 0.8273381294964028
# specificity: 1.0
# precision: 1.0
# accuracy: 0.8344827586206897
# f1_score: 0.905511811023622
# 121 3 6 2
# isolate: ecol-SAMN15148053
# recall: 0.983739837398374
# specificity: 0.6666666666666666
# precision: 0.9758064516129032
# accuracy: 0.9621212121212122
# f1_score: 0.979757085020243
# 152 5 3 2
# isolate: ecol-SAMN15148054
# recall: 0.987012987012987
# specificity: 0.375
# precision: 0.9681528662420382
# accuracy: 0.9567901234567902
# f1_score: 0.977491961414791
# 238 12 18 23
# isolate: ecol-SAMN15148060
# recall: 0.9118773946360154
# specificity: 0.6
# precision: 0.952
# accuracy: 0.8797250859106529
# f1_score: 0.9315068493150684
# 175 2 1 17
# isolate: ecol-SAMN15148070
# recall: 0.9114583333333334
# specificity: 0.3333333333333333
# precision: 0.9887005649717514
# accuracy: 0.9025641025641026
# f1_score: 0.9485094850948509
# 135 0 2 1
# isolate: ecol-SAMN15148072
# recall: 0.9926470588235294
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9927536231884058
# f1_score: 0.996309963099631
# 149 14 5 5
# isolate: ecol-SAMN15148083
# recall: 0.9675324675324676
# specificity: 0.2631578947368421
# precision: 0.9141104294478528
# accuracy: 0.8901734104046243
# f1_score: 0.9400630914826498
# 263 20 12 7
# isolate: ecol-SAMN15148089
# recall: 0.9740740740740741
# specificity: 0.375
# precision: 0.9293286219081273
# accuracy: 0.9105960264900662
# f1_score: 0.9511754068716094
# 266 22 7 5
# isolate: ecol-SAMN15148090
# recall: 0.981549815498155
# specificity: 0.2413793103448276
# precision: 0.9236111111111112
# accuracy: 0.91
# f1_score: 0.9516994633273704
# 210 18 8 5
# isolate: ecol-SAMN15148091
# recall: 0.9767441860465116
# specificity: 0.3076923076923077
# precision: 0.9210526315789473
# accuracy: 0.9045643153526971
# f1_score: 0.9480812641083521
# 50 2 2 2
# isolate: ecol-SAMN15148093
# recall: 0.9615384615384616
# specificity: 0.5
# precision: 0.9615384615384616
# accuracy: 0.9285714285714286
# f1_score: 0.9615384615384616
# 49 0 1 1
# isolate: ecol-SAMN15148094
# recall: 0.98
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9803921568627451
# f1_score: 0.98989898989899
# 100 2 5 5
# isolate: ecol-SAMN15148099
# recall: 0.9523809523809523
# specificity: 0.7142857142857143
# precision: 0.9803921568627451
# accuracy: 0.9375
# f1_score: 0.966183574879227
# 125 1 3 8
# isolate: ecol-SAMN15148100
# recall: 0.9398496240601504
# specificity: 0.75
# precision: 0.9920634920634921
# accuracy: 0.9343065693430657
# f1_score: 0.9652509652509653
# 60 0 8 2
# isolate: ecol-SAMN15148101
# recall: 0.967741935483871
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9714285714285714
# f1_score: 0.9836065573770492
# 67 1 6 11
# isolate: ecol-SAMN15148102
# recall: 0.8589743589743589
# specificity: 0.8571428571428571
# precision: 0.9852941176470589
# accuracy: 0.8588235294117647
# f1_score: 0.9178082191780821
# 160 16 33 19
# isolate: ecol-SAMN15148111
# recall: 0.8938547486033519
# specificity: 0.673469387755102
# precision: 0.9090909090909091
# accuracy: 0.8464912280701754
# f1_score: 0.9014084507042253
# 67 0 30 4
# isolate: ecol-SAMN15148112
# recall: 0.9436619718309859
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9603960396039604
# f1_score: 0.9710144927536231
# 264 15 59 26
# isolate: ecol-SAMN15148118
# recall: 0.9103448275862069
# specificity: 0.7972972972972973
# precision: 0.946236559139785
# accuracy: 0.8873626373626373
# f1_score: 0.9279437609841829
# 118 8 2 27
# isolate: ecol-SAMN15148121
# recall: 0.8137931034482758
# specificity: 0.2
# precision: 0.9365079365079365
# accuracy: 0.7741935483870968
# f1_score: 0.8708487084870848
# 267 12 63 24
# isolate: ecol-SAMN15148127
# recall: 0.9175257731958762
# specificity: 0.84
# precision: 0.956989247311828
# accuracy: 0.9016393442622951
# f1_score: 0.9368421052631579
# 258 24 76 43
# isolate: ecol-SAMN15148136
# recall: 0.8571428571428571
# specificity: 0.76
# precision: 0.9148936170212766
# accuracy: 0.8329177057356608
# f1_score: 0.8850771869639794
# 134 13 12 1
# isolate: ecol-SAMN15148138
# recall: 0.9925925925925926
# specificity: 0.48
# precision: 0.9115646258503401
# accuracy: 0.9125
# f1_score: 0.9503546099290779
# 122 18 15 8
# isolate: ecol-SAMN15148139
# recall: 0.9384615384615385
# specificity: 0.45454545454545453
# precision: 0.8714285714285714
# accuracy: 0.8404907975460123
# f1_score: 0.9037037037037037
# 202 7 20 23
# isolate: ecol-SAMN15148143
# recall: 0.8977777777777778
# specificity: 0.7407407407407407
# precision: 0.9665071770334929
# accuracy: 0.8809523809523809
# f1_score: 0.9308755760368664
# 94 5 8 11
# isolate: ecol-SAMN15148145
# recall: 0.8952380952380953
# specificity: 0.6153846153846154
# precision: 0.9494949494949495
# accuracy: 0.864406779661017
# f1_score: 0.9215686274509803
# 61 6 2 0
# isolate: ecol-SAMN15148148
# recall: 1.0
# specificity: 0.25
# precision: 0.9104477611940298
# accuracy: 0.9130434782608695
# f1_score: 0.953125
# 90 0 1 1
# isolate: ecol-SAMN15148149
# recall: 0.989010989010989
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9891304347826086
# f1_score: 0.994475138121547
# 372 3 15 66
# isolate: ecol-SAMN15148177
# recall: 0.8493150684931506
# specificity: 0.8333333333333334
# precision: 0.992
# accuracy: 0.8486842105263158
# f1_score: 0.915129151291513
# 102 13 7 2
# isolate: ecol-SAMN15148207
# recall: 0.9807692307692307
# specificity: 0.35
# precision: 0.8869565217391304
# accuracy: 0.8790322580645161
# f1_score: 0.9315068493150686
# 102 1 17 5
# isolate: ecol-SAMN15148215
# recall: 0.9532710280373832
# specificity: 0.9444444444444444
# precision: 0.9902912621359223
# accuracy: 0.952
# f1_score: 0.9714285714285714
# 127 3 5 3
# isolate: ecol-SAMN15148217
# recall: 0.9769230769230769
# specificity: 0.625
# precision: 0.9769230769230769
# accuracy: 0.9565217391304348
# f1_score: 0.9769230769230769
# 152 0 19 3
# isolate: ecol-SAMN15148218
# recall: 0.9806451612903225
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9827586206896551
# f1_score: 0.990228013029316
# 268 6 0 3
# isolate: ecol-SAMN15148228
# recall: 0.988929889298893
# specificity: 0.0
# precision: 0.9781021897810219
# accuracy: 0.9675090252707581
# f1_score: 0.98348623853211
# 95 21 2 2
# isolate: ecol-SAMN15148229
# recall: 0.979381443298969
# specificity: 0.08695652173913043
# precision: 0.8189655172413793
# accuracy: 0.8083333333333333
# f1_score: 0.892018779342723
# 262 9 21 122
# isolate: ecol-SAMN15148263
# recall: 0.6822916666666666
# specificity: 0.7
# precision: 0.966789667896679
# accuracy: 0.6835748792270532
# f1_score: 0.7999999999999999
# 121 14 16 13
# isolate: ecol-SAMN15148267
# recall: 0.9029850746268657
# specificity: 0.5333333333333333
# precision: 0.8962962962962963
# accuracy: 0.8353658536585366
# f1_score: 0.899628252788104
# 147 6 1 15
# isolate: ecol-SAMN15148268
# recall: 0.9074074074074074
# specificity: 0.14285714285714285
# precision: 0.9607843137254902
# accuracy: 0.8757396449704142
# f1_score: 0.9333333333333333
# 168 0 3 8
# isolate: ecol-SAMN15148273
# recall: 0.9545454545454546
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9553072625698324
# f1_score: 0.9767441860465117
# 237 12 19 19
# isolate: ecol-SAMN15148298
# recall: 0.92578125
# specificity: 0.6129032258064516
# precision: 0.9518072289156626
# accuracy: 0.89198606271777
# f1_score: 0.9386138613861386
# 108 0 3 9
# isolate: ecol-SAMN15148314
# recall: 0.9230769230769231
# specificity: 1.0
# precision: 1.0
# accuracy: 0.925
# f1_score: 0.9600000000000001
# 98 3 26 10
# isolate: ecol-SAMN15148328
# recall: 0.9074074074074074
# specificity: 0.896551724137931
# precision: 0.9702970297029703
# accuracy: 0.9051094890510949
# f1_score: 0.937799043062201
# 84 3 5 0
# isolate: ecol-SAMN15148331
# recall: 1.0
# specificity: 0.625
# precision: 0.9655172413793104
# accuracy: 0.967391304347826
# f1_score: 0.9824561403508771
# 56 1 5 4
# isolate: ecol-SAMN15148349
# recall: 0.9333333333333333
# specificity: 0.8333333333333334
# precision: 0.9824561403508771
# accuracy: 0.9242424242424242
# f1_score: 0.9572649572649572
# 217 16 71 29
# isolate: ecol-SAMN15148350
# recall: 0.8821138211382114
# specificity: 0.8160919540229885
# precision: 0.9313304721030042
# accuracy: 0.8648648648648649
# f1_score: 0.906054279749478
# 213 4 1 10
# isolate: ecol-SAMN15148351
# recall: 0.9551569506726457
# specificity: 0.2
# precision: 0.9815668202764977
# accuracy: 0.9385964912280702
# f1_score: 0.9681818181818181
# 100 0 2 1
# isolate: ecol-SAMN15148359
# recall: 0.9900990099009901
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9902912621359223
# f1_score: 0.9950248756218906
# 139 7 0 6
# isolate: ecol-SAMN15148360
# recall: 0.9586206896551724
# specificity: 0.0
# precision: 0.952054794520548
# accuracy: 0.9144736842105263
# f1_score: 0.9553264604810997
# 144 7 0 23
# isolate: ecol-SAMN15148362
# recall: 0.8622754491017964
# specificity: 0.0
# precision: 0.9536423841059603
# accuracy: 0.8275862068965517
# f1_score: 0.9056603773584905
# 131 5 7 5
# isolate: ecol-SAMN15148366
# recall: 0.9632352941176471
# specificity: 0.5833333333333334
# precision: 0.9632352941176471
# accuracy: 0.9324324324324325
# f1_score: 0.9632352941176471
# 226 1 5 24
# isolate: ecol-SAMN15148368
# recall: 0.904
# specificity: 0.8333333333333334
# precision: 0.9955947136563876
# accuracy: 0.90234375
# f1_score: 0.9475890985324947
# 134 0 104 3
# isolate: ecol-SAMN15148379
# recall: 0.9781021897810219
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9875518672199171
# f1_score: 0.988929889298893
# 203 4 34 64
# isolate: ecol-SAMN15148387
# recall: 0.7602996254681648
# specificity: 0.8947368421052632
# precision: 0.9806763285024155
# accuracy: 0.7770491803278688
# f1_score: 0.8565400843881856
# 160 2 81 107
# isolate: ecol-SAMN15148388
# recall: 0.599250936329588
# specificity: 0.9759036144578314
# precision: 0.9876543209876543
# accuracy: 0.6885714285714286
# f1_score: 0.7459207459207459
# 286 2 58 168
# isolate: ecol-SAMN15148391
# recall: 0.6299559471365639
# specificity: 0.9666666666666667
# precision: 0.9930555555555556
# accuracy: 0.669260700389105
# f1_score: 0.77088948787062
# 199 3 4 4
# isolate: ecol-SAMN15148397
# recall: 0.9802955665024631
# specificity: 0.5714285714285714
# precision: 0.9851485148514851
# accuracy: 0.9666666666666667
# f1_score: 0.9827160493827161
# 205 1 55 10
# isolate: ecol-SAMN15148400
# recall: 0.9534883720930233
# specificity: 0.9821428571428571
# precision: 0.9951456310679612
# accuracy: 0.959409594095941
# f1_score: 0.9738717339667458
# 123 15 15 19
# isolate: ecol-SAMN15148423
# recall: 0.8661971830985915
# specificity: 0.5
# precision: 0.8913043478260869
# accuracy: 0.8023255813953488
# f1_score: 0.8785714285714286
# 139 63 83 16
# isolate: ecol-SAMN15148426
# recall: 0.896774193548387
# specificity: 0.5684931506849316
# precision: 0.6881188118811881
# accuracy: 0.7375415282392026
# f1_score: 0.7787114845938375
# 133 0 3 5
# isolate: ecol-SAMN15148433
# recall: 0.9637681159420289
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9645390070921985
# f1_score: 0.981549815498155
# 170 1 2 2
# isolate: ecol-SAMN15148461
# recall: 0.9883720930232558
# specificity: 0.6666666666666666
# precision: 0.9941520467836257
# accuracy: 0.9828571428571429
# f1_score: 0.9912536443148688
# 150 5 76 12
# isolate: ecol-SAMN15148475
# recall: 0.9259259259259259
# specificity: 0.9382716049382716
# precision: 0.967741935483871
# accuracy: 0.9300411522633745
# f1_score: 0.9463722397476341
# 184 62 40 53
# isolate: ecol-SAMN15148482
# recall: 0.7763713080168776
# specificity: 0.39215686274509803
# precision: 0.7479674796747967
# accuracy: 0.6607669616519174
# f1_score: 0.7619047619047619
# 140 0 0 3
# isolate: ecol-SAMN15148483
# recall: 0.9790209790209791
# specificity: nan
# precision: 1.0
# accuracy: 0.9790209790209791
# f1_score: 0.989399293286219
# 171 1 57 5
# isolate: ecol-SAMN15148515
# recall: 0.9715909090909091
# specificity: 0.9827586206896551
# precision: 0.9941860465116279
# accuracy: 0.9743589743589743
# f1_score: 0.9827586206896551
# 87 0 6 8
# isolate: ecol-SAMN15148547
# recall: 0.9157894736842105
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9207920792079208
# f1_score: 0.956043956043956
# 132 4 5 11
# isolate: ecol-SAMN15148548
# recall: 0.9230769230769231
# specificity: 0.5555555555555556
# precision: 0.9705882352941176
# accuracy: 0.9013157894736842
# f1_score: 0.946236559139785
# 166 36 6 14
# isolate: ecol-SAMN15148563
# recall: 0.9222222222222223
# specificity: 0.14285714285714285
# precision: 0.8217821782178217
# accuracy: 0.7747747747747747
# f1_score: 0.869109947643979
# 205 4 0 11
# isolate: ecol-SAMN15148570
# recall: 0.9490740740740741
# specificity: 0.0
# precision: 0.9808612440191388
# accuracy: 0.9318181818181818
# f1_score: 0.9647058823529412
# 153 34 30 12
# isolate: ecol-SAMN15148576
# recall: 0.9272727272727272
# specificity: 0.46875
# precision: 0.8181818181818182
# accuracy: 0.7991266375545851
# f1_score: 0.8693181818181819
# 216 1 0 19
# isolate: ecol-SAMN15148585
# recall: 0.9191489361702128
# specificity: 0.0
# precision: 0.9953917050691244
# accuracy: 0.9152542372881356
# f1_score: 0.9557522123893805
# 102 20 0 2
# isolate: ecol-SAMN15148591
# recall: 0.9807692307692307
# specificity: 0.0
# precision: 0.8360655737704918
# accuracy: 0.8225806451612904
# f1_score: 0.9026548672566372
# 204 7 16 21
# isolate: ecol-SAMN15148593
# recall: 0.9066666666666666
# specificity: 0.6956521739130435
# precision: 0.966824644549763
# accuracy: 0.8870967741935484
# f1_score: 0.9357798165137615
# 188 24 83 16
# isolate: ecol-SAMN15148596
# recall: 0.9215686274509803
# specificity: 0.7757009345794392
# precision: 0.8867924528301887
# accuracy: 0.8713826366559485
# f1_score: 0.9038461538461539
# 389 4 58 34
# isolate: ecol-SAMN15148605
# recall: 0.9196217494089834
# specificity: 0.9354838709677419
# precision: 0.989821882951654
# accuracy: 0.9216494845360824
# f1_score: 0.9534313725490196
# 200 0 13 5
# isolate: ecol-SAMN15148627
# recall: 0.975609756097561
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9770642201834863
# f1_score: 0.9876543209876543
# 164 1 32 97
# isolate: ecol-SAMN15148648
# recall: 0.6283524904214559
# specificity: 0.9696969696969697
# precision: 0.9939393939393939
# accuracy: 0.6666666666666666
# f1_score: 0.7699530516431924
# 108 1 13 14
# isolate: ecol-SAMN15148701
# recall: 0.8852459016393442
# specificity: 0.9285714285714286
# precision: 0.9908256880733946
# accuracy: 0.8897058823529411
# f1_score: 0.9350649350649352
# 115 7 17 12
# isolate: ecol-SAMN15148710
# recall: 0.905511811023622
# specificity: 0.7083333333333334
# precision: 0.9426229508196722
# accuracy: 0.8741721854304636
# f1_score: 0.9236947791164659
# 98 0 1 4
# isolate: ecol-SAMN15148714
# recall: 0.9607843137254902
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9611650485436893
# f1_score: 0.98
# 118 2 0 14
# isolate: ecol-SAMN15148720
# recall: 0.8939393939393939
# specificity: 0.0
# precision: 0.9833333333333333
# accuracy: 0.8805970149253731
# f1_score: 0.9365079365079364
# 174 1 14 14
# isolate: ecol-SAMN15148732
# recall: 0.925531914893617
# specificity: 0.9333333333333333
# precision: 0.9942857142857143
# accuracy: 0.9261083743842364
# f1_score: 0.9586776859504131
# 131 1 1 9
# isolate: ecol-SAMN15148739
# recall: 0.9357142857142857
# specificity: 0.5
# precision: 0.9924242424242424
# accuracy: 0.9295774647887324
# f1_score: 0.9632352941176471
# 122 51 2 6
# isolate: ecol-SAMN21365996
# recall: 0.953125
# specificity: 0.03773584905660377
# precision: 0.7052023121387283
# accuracy: 0.6850828729281768
# f1_score: 0.8106312292358804
# 161 23 10 6
# isolate: ecol-SAMN21365997
# recall: 0.9640718562874252
# specificity: 0.30303030303030304
# precision: 0.875
# accuracy: 0.855
# f1_score: 0.9173789173789174
# 118 1 14 13
# isolate: ecol-SAMN21366003
# recall: 0.9007633587786259
# specificity: 0.9333333333333333
# precision: 0.9915966386554622
# accuracy: 0.9041095890410958
# f1_score: 0.944
# 187 177 5 11
# isolate: ecol-SAMN21366006
# recall: 0.9444444444444444
# specificity: 0.027472527472527472
# precision: 0.5137362637362637
# accuracy: 0.5052631578947369
# f1_score: 0.6654804270462633
# 184 52 31 25
# isolate: ecol-SAMN21366010
# recall: 0.8803827751196173
# specificity: 0.37349397590361444
# precision: 0.7796610169491526
# accuracy: 0.7363013698630136
# f1_score: 0.8269662921348315
# 187 11 37 24
# isolate: ecol-SAMN21366012
# recall: 0.8862559241706162
# specificity: 0.7708333333333334
# precision: 0.9444444444444444
# accuracy: 0.8648648648648649
# f1_score: 0.9144254278728607
# 121 13 21 4
# isolate: ecol-SAMN21366015
# recall: 0.968
# specificity: 0.6176470588235294
# precision: 0.9029850746268657
# accuracy: 0.8930817610062893
# f1_score: 0.9343629343629344
# 196 20 11 10
# isolate: ecol-SAMN21366016
# recall: 0.9514563106796117
# specificity: 0.3548387096774194
# precision: 0.9074074074074074
# accuracy: 0.8734177215189873
# f1_score: 0.9289099526066351
# 152 23 34 18
# isolate: ecol-SAMN21366024
# recall: 0.8941176470588236
# specificity: 0.5964912280701754
# precision: 0.8685714285714285
# accuracy: 0.8193832599118943
# f1_score: 0.8811594202898549
# 54 4 16 15
# isolate: ecol-SAMN21366035
# recall: 0.782608695652174
# specificity: 0.8
# precision: 0.9310344827586207
# accuracy: 0.7865168539325843
# f1_score: 0.8503937007874016
# 167 18 15 19
# isolate: ecol-SAMN21366039
# recall: 0.8978494623655914
# specificity: 0.45454545454545453
# precision: 0.9027027027027027
# accuracy: 0.8310502283105022
# f1_score: 0.9002695417789757
# 210 7 2 17
# isolate: ecol-SAMN21366041
# recall: 0.9251101321585903
# specificity: 0.2222222222222222
# precision: 0.967741935483871
# accuracy: 0.8983050847457628
# f1_score: 0.9459459459459458
# 192 21 42 16
# isolate: ecol-SAMN21366042
# recall: 0.9230769230769231
# specificity: 0.6666666666666666
# precision: 0.9014084507042254
# accuracy: 0.8634686346863468
# f1_score: 0.9121140142517815
# 159 4 19 8
# isolate: ecol-SAMN21366045
# recall: 0.9520958083832335
# specificity: 0.8260869565217391
# precision: 0.9754601226993865
# accuracy: 0.9368421052631579
# f1_score: 0.9636363636363636
# 160 10 13 17
# isolate: ecol-SAMN21366046
# recall: 0.903954802259887
# specificity: 0.5652173913043478
# precision: 0.9411764705882353
# accuracy: 0.865
# f1_score: 0.9221902017291066
# 188 12 12 5
# isolate: ecol-SAMN21366053
# recall: 0.9740932642487047
# specificity: 0.5
# precision: 0.94
# accuracy: 0.9216589861751152
# f1_score: 0.9567430025445293
# 151 26 22 14
# isolate: ecol-SAMN21366054
# recall: 0.9151515151515152
# specificity: 0.4583333333333333
# precision: 0.8531073446327684
# accuracy: 0.812206572769953
# f1_score: 0.8830409356725145
# 207 6 12 21
# isolate: ecol-SAMN21366055
# recall: 0.9078947368421053
# specificity: 0.6666666666666666
# precision: 0.971830985915493
# accuracy: 0.8902439024390244
# f1_score: 0.9387755102040817
# 103 5 5 6
# isolate: ecol-SAMN21366059
# recall: 0.944954128440367
# specificity: 0.5
# precision: 0.9537037037037037
# accuracy: 0.907563025210084
# f1_score: 0.9493087557603688
# 229 38 31 5
# isolate: ecol-SAMN21366065
# recall: 0.9786324786324786
# specificity: 0.4492753623188406
# precision: 0.8576779026217228
# accuracy: 0.858085808580858
# f1_score: 0.9141716566866267
# 160 27 14 33
# isolate: ecol-SAMN21366066
# recall: 0.8290155440414507
# specificity: 0.34146341463414637
# precision: 0.8556149732620321
# accuracy: 0.7435897435897436
# f1_score: 0.8421052631578947
# 108 31 12 1
# isolate: ecol-SAMN21366068
# recall: 0.9908256880733946
# specificity: 0.27906976744186046
# precision: 0.7769784172661871
# accuracy: 0.7894736842105263
# f1_score: 0.8709677419354839
# 147 29 106 8
# isolate: ecol-SAMN21366072
# recall: 0.9483870967741935
# specificity: 0.7851851851851852
# precision: 0.8352272727272727
# accuracy: 0.8724137931034482
# f1_score: 0.8882175226586102
# 282 24 31 19
# isolate: ecol-SAMN21366074
# recall: 0.9368770764119602
# specificity: 0.5636363636363636
# precision: 0.9215686274509803
# accuracy: 0.8792134831460674
# f1_score: 0.929159802306425
# 401 49 50 37
# isolate: ecol-SAMN21366078
# recall: 0.9155251141552512
# specificity: 0.5050505050505051
# precision: 0.8911111111111111
# accuracy: 0.839851024208566
# f1_score: 0.9031531531531531
# 328 46 47 21
# isolate: ecol-SAMN21366079
# recall: 0.9398280802292264
# specificity: 0.5053763440860215
# precision: 0.8770053475935828
# accuracy: 0.8484162895927602
# f1_score: 0.9073305670816044
# 181 79 31 14
# isolate: ecol-SAMN21366080
# recall: 0.9282051282051282
# specificity: 0.2818181818181818
# precision: 0.6961538461538461
# accuracy: 0.6950819672131148
# f1_score: 0.7956043956043956
# 164 57 8 13
# isolate: ecol-SAMN21366081
# recall: 0.9265536723163842
# specificity: 0.12307692307692308
# precision: 0.7420814479638009
# accuracy: 0.7107438016528925
# f1_score: 0.8241206030150755
# 154 8 17 32
# isolate: ecol-SAMN21366082
# recall: 0.8279569892473119
# specificity: 0.68
# precision: 0.9506172839506173
# accuracy: 0.8104265402843602
# f1_score: 0.885057471264368
# 171 50 32 22
# isolate: ecol-SAMN21366083
# recall: 0.8860103626943006
# specificity: 0.3902439024390244
# precision: 0.7737556561085973
# accuracy: 0.7381818181818182
# f1_score: 0.8260869565217391
# 230 246 30 6
# isolate: ecol-SAMN21366084
# recall: 0.9745762711864406
# specificity: 0.10869565217391304
# precision: 0.4831932773109244
# accuracy: 0.5078125
# f1_score: 0.6460674157303371
