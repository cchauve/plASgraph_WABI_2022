# %%
import pandas as pd
import numpy as np

from glob import glob

# %% [markdown]
# __C. freundii__

# %%
species = "c_freundii"

# %%
prediction_files = glob("../results/generalized/" + species + "/*.csv")

# %%
# metrics using all input sequences

for prediction_file in prediction_files:

    if "metrics" in prediction_file:
        continue

    prediction_df = pd.read_csv(prediction_file, index_col=0)

    isolate = "_".join(prediction_file.split("\\")[-1].split("_")[0:-3])

    minimap2_df = pd.read_csv(
        "../data/alignment_files/"
        + species
        + "/"
        + isolate
        + "_minimap_alignment_labelled_ambiguity_cutoff_1.csv",
        index_col=0,
    )

    tp = 0
    fp = 0
    tn = 0
    fn = 0

    for contig_name, row in prediction_df.iterrows():
        try:  # not all sequences in the graph file are also in the assembly fasta, leading to key error
            # if minimap2_df.loc[contig_name,"short_read_contig_length"] <= 1000:
            #    continue
            # if minimap2_df.loc[contig_name,"label"] == "ambiguous":
            #    continue
            if (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tp += 1
            elif (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fp += 1
            elif not (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fn += 1
            elif not (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tn += 1
        except KeyError:
            pass

    print(tp, fp, tn, fn)

    try:
        recall = tp / (tp + fn)  # TP / P = TP / (TP + FN)
    except ZeroDivisionError:
        recall = np.nan
    specificity = tn / (tn + fp)  # TN / N = TN / (TN + FP)
    try:
        precision = tp / (tp + fp)  # TP / (TP + FP)
    except ZeroDivisionError:
        precision = np.nan
    accuracy = (tp + tn) / (
        tp + tn + fp + fn
    )  # T / all = (TP + TN) / (TP + TN + FP + FN)
    try:
        f1_score = 2 * (
            (recall * precision) / (recall + precision)
        )  # harmonic mean of precision and recall
    except ZeroDivisionError:
        f1_score = np.nan

    print("isolate:", isolate)
    print("recall:", recall)
    print("specificity:", specificity)
    print("precision:", precision)
    print("accuracy:", accuracy)
    print("f1_score:", f1_score)

    result_df = pd.DataFrame(
        [[isolate, recall, specificity, precision, accuracy, f1_score, tp, fp, fn, tn]],
        columns=[
            "isolate",
            "recall",
            "specificity",
            "precision",
            "accuracy",
            "f1_score",
            "tp",
            "fp",
            "fn",
            "tn",
        ],
    )

    result_df.to_csv(
        prediction_file[:-4] + "_metrics_all_ambiguous_equal_plasmid.csv", index=False
    )
# Out:
# 0 0 57 0
# isolate: c_freundii_001
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 53 17 92 7
# isolate: c_freundii_002
# recall: 0.8833333333333333
# specificity: 0.8440366972477065
# precision: 0.7571428571428571
# accuracy: 0.8579881656804734
# f1_score: 0.8153846153846154
# 55 9 75 11
# isolate: c_freundii_003
# recall: 0.8333333333333334
# specificity: 0.8928571428571429
# precision: 0.859375
# accuracy: 0.8666666666666667
# f1_score: 0.8461538461538461
# 23 15 56 3
# isolate: c_freundii_004
# recall: 0.8846153846153846
# specificity: 0.7887323943661971
# precision: 0.6052631578947368
# accuracy: 0.8144329896907216
# f1_score: 0.71875
# 0 11 91 0
# isolate: c_freundii_005
# recall: nan
# specificity: 0.8921568627450981
# precision: 0.0
# accuracy: 0.8921568627450981
# f1_score: nan
# 44 28 100 5
# isolate: c_freundii_006
# recall: 0.8979591836734694
# specificity: 0.78125
# precision: 0.6111111111111112
# accuracy: 0.8135593220338984
# f1_score: 0.7272727272727272
# 38 19 112 14
# isolate: c_freundii_007
# recall: 0.7307692307692307
# specificity: 0.8549618320610687
# precision: 0.6666666666666666
# accuracy: 0.819672131147541
# f1_score: 0.6972477064220183
# 0 0 50 0
# isolate: c_freundii_008
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 0 1 39 0
# isolate: c_freundii_009
# recall: nan
# specificity: 0.975
# precision: 0.0
# accuracy: 0.975
# f1_score: nan
# 0 0 54 0
# isolate: c_freundii_010
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 10 4 74 5
# isolate: c_freundii_011
# recall: 0.6666666666666666
# specificity: 0.9487179487179487
# precision: 0.7142857142857143
# accuracy: 0.9032258064516129
# f1_score: 0.689655172413793
# 9 19 89 5
# isolate: c_freundii_012
# recall: 0.6428571428571429
# specificity: 0.8240740740740741
# precision: 0.32142857142857145
# accuracy: 0.8032786885245902
# f1_score: 0.4285714285714286
# 2 12 58 5
# isolate: c_freundii_013
# recall: 0.2857142857142857
# specificity: 0.8285714285714286
# precision: 0.14285714285714285
# accuracy: 0.7792207792207793
# f1_score: 0.19047619047619047
# 54 79 91 1
# isolate: c_freundii_014
# recall: 0.9818181818181818
# specificity: 0.5352941176470588
# precision: 0.40601503759398494
# accuracy: 0.6444444444444445
# f1_score: 0.5744680851063829
# 0 2 73 0
# isolate: c_freundii_015
# recall: nan
# specificity: 0.9733333333333334
# precision: 0.0
# accuracy: 0.9733333333333334
# f1_score: nan
# 1 0 28 0
# isolate: c_freundii_016
# recall: 1.0
# specificity: 1.0
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 0 0 39 0
# isolate: c_freundii_017
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 23 6 50 4
# isolate: c_freundii_018
# recall: 0.8518518518518519
# specificity: 0.8928571428571429
# precision: 0.7931034482758621
# accuracy: 0.8795180722891566
# f1_score: 0.8214285714285715
# 0 1 67 2
# isolate: c_freundii_019
# recall: 0.0
# specificity: 0.9852941176470589
# precision: 0.0
# accuracy: 0.9571428571428572
# f1_score: nan
# 0 0 37 0
# isolate: c_freundii_020
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 66 20 84 9
# isolate: c_freundii_021
# recall: 0.88
# specificity: 0.8076923076923077
# precision: 0.7674418604651163
# accuracy: 0.8379888268156425
# f1_score: 0.8198757763975156
# 6 1 60 0
# isolate: c_freundii_022
# recall: 1.0
# specificity: 0.9836065573770492
# precision: 0.8571428571428571
# accuracy: 0.9850746268656716
# f1_score: 0.923076923076923
# 21 0 103 16
# isolate: c_freundii_023
# recall: 0.5675675675675675
# specificity: 1.0
# precision: 1.0
# accuracy: 0.8857142857142857
# f1_score: 0.7241379310344828
# 15 31 110 7
# isolate: c_freundii_024
# recall: 0.6818181818181818
# specificity: 0.7801418439716312
# precision: 0.32608695652173914
# accuracy: 0.7668711656441718
# f1_score: 0.4411764705882353
# 11 0 33 0
# isolate: c_freundii_025
# recall: 1.0
# specificity: 1.0
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 35 4 127 7
# isolate: c_freundii_026
# recall: 0.8333333333333334
# specificity: 0.9694656488549618
# precision: 0.8974358974358975
# accuracy: 0.9364161849710982
# f1_score: 0.8641975308641975
# 0 0 29 0
# isolate: c_freundii_027
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 98 7 65 20
# isolate: c_freundii_030
# recall: 0.8305084745762712
# specificity: 0.9027777777777778
# precision: 0.9333333333333333
# accuracy: 0.8578947368421053
# f1_score: 0.8789237668161435
# 38 9 92 47
# isolate: c_freundii_031
# recall: 0.4470588235294118
# specificity: 0.9108910891089109
# precision: 0.8085106382978723
# accuracy: 0.6989247311827957
# f1_score: 0.5757575757575757
# 0 3 51 0
# isolate: c_freundii_033
# recall: nan
# specificity: 0.9444444444444444
# precision: 0.0
# accuracy: 0.9444444444444444
# f1_score: nan
# 0 0 50 0
# isolate: c_freundii_034
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 0 34 87 0
# isolate: c_freundii_035
# recall: nan
# specificity: 0.71900826446281
# precision: 0.0
# accuracy: 0.71900826446281
# f1_score: nan
# 0 2 52 0
# isolate: c_freundii_036
# recall: nan
# specificity: 0.9629629629629629
# precision: 0.0
# accuracy: 0.9629629629629629
# f1_score: nan
# 1 11 82 7
# isolate: c_freundii_037
# recall: 0.125
# specificity: 0.8817204301075269
# precision: 0.08333333333333333
# accuracy: 0.8217821782178217
# f1_score: 0.1
# 64 1 66 3
# isolate: c_freundii_038
# recall: 0.9552238805970149
# specificity: 0.9850746268656716
# precision: 0.9846153846153847
# accuracy: 0.9701492537313433
# f1_score: 0.9696969696969696
# 40 8 99 13
# isolate: c_freundii_039
# recall: 0.7547169811320755
# specificity: 0.9252336448598131
# precision: 0.8333333333333334
# accuracy: 0.86875
# f1_score: 0.7920792079207922
# 37 14 96 15
# isolate: c_freundii_040
# recall: 0.7115384615384616
# specificity: 0.8727272727272727
# precision: 0.7254901960784313
# accuracy: 0.8209876543209876
# f1_score: 0.7184466019417477
# 41 8 62 11
# isolate: c_freundii_041
# recall: 0.7884615384615384
# specificity: 0.8857142857142857
# precision: 0.8367346938775511
# accuracy: 0.8442622950819673
# f1_score: 0.8118811881188118
# 43 10 59 10
# isolate: c_freundii_042
# recall: 0.8113207547169812
# specificity: 0.855072463768116
# precision: 0.8113207547169812
# accuracy: 0.8360655737704918
# f1_score: 0.8113207547169812
# 44 20 93 23
# isolate: c_freundii_043
# recall: 0.6567164179104478
# specificity: 0.8230088495575221
# precision: 0.6875
# accuracy: 0.7611111111111111
# f1_score: 0.6717557251908397
# 95 4 73 22
# isolate: c_freundii_044
# recall: 0.811965811965812
# specificity: 0.948051948051948
# precision: 0.9595959595959596
# accuracy: 0.865979381443299
# f1_score: 0.8796296296296297
# 32 18 91 38
# isolate: c_freundii_045
# recall: 0.45714285714285713
# specificity: 0.8348623853211009
# precision: 0.64
# accuracy: 0.6871508379888268
# f1_score: 0.5333333333333333
# 43 23 99 5
# isolate: c_freundii_046
# recall: 0.8958333333333334
# specificity: 0.8114754098360656
# precision: 0.6515151515151515
# accuracy: 0.8352941176470589
# f1_score: 0.7543859649122807
# 0 5 50 0
# isolate: c_freundii_047
# recall: nan
# specificity: 0.9090909090909091
# precision: 0.0
# accuracy: 0.9090909090909091
# f1_score: nan
# 38 17 48 0
# isolate: c_freundii_048
# recall: 1.0
# specificity: 0.7384615384615385
# precision: 0.6909090909090909
# accuracy: 0.8349514563106796
# f1_score: 0.8172043010752689
# 0 0 64 0
# isolate: c_freundii_049
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 0 0 42 0
# isolate: c_freundii_050
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 0 0 44 0
# isolate: c_freundii_051
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 35 21 102 5
# isolate: c_freundii_052
# recall: 0.875
# specificity: 0.8292682926829268
# precision: 0.625
# accuracy: 0.8404907975460123
# f1_score: 0.7291666666666666
# 34 6 49 14
# isolate: c_freundii_053
# recall: 0.7083333333333334
# specificity: 0.8909090909090909
# precision: 0.85
# accuracy: 0.8058252427184466
# f1_score: 0.7727272727272727
# 45 19 64 7
# isolate: c_freundii_054
# recall: 0.8653846153846154
# specificity: 0.7710843373493976
# precision: 0.703125
# accuracy: 0.8074074074074075
# f1_score: 0.7758620689655172
# 0 6 62 0
# isolate: c_freundii_055
# recall: nan
# specificity: 0.9117647058823529
# precision: 0.0
# accuracy: 0.9117647058823529
# f1_score: nan
# 0 4 61 0
# isolate: c_freundii_056
# recall: nan
# specificity: 0.9384615384615385
# precision: 0.0
# accuracy: 0.9384615384615385
# f1_score: nan
# 0 4 63 0
# isolate: c_freundii_057
# recall: nan
# specificity: 0.9402985074626866
# precision: 0.0
# accuracy: 0.9402985074626866
# f1_score: nan
# 0 2 44 0
# isolate: c_freundii_058
# recall: nan
# specificity: 0.9565217391304348
# precision: 0.0
# accuracy: 0.9565217391304348
# f1_score: nan
# 0 0 36 0
# isolate: c_freundii_059
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 0 0 35 0
# isolate: c_freundii_060
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 0 0 33 0
# isolate: c_freundii_061
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 0 11 55 0
# isolate: c_freundii_062
# recall: nan
# specificity: 0.8333333333333334
# precision: 0.0
# accuracy: 0.8333333333333334
# f1_score: nan
# 1 0 45 0
# isolate: c_freundii_063
# recall: 1.0
# specificity: 1.0
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 32 4 64 6
# isolate: c_freundii_064
# recall: 0.8421052631578947
# specificity: 0.9411764705882353
# precision: 0.8888888888888888
# accuracy: 0.9056603773584906
# f1_score: 0.8648648648648649
# 0 0 76 0
# isolate: c_freundii_065
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 1 6 65 0
# isolate: c_freundii_066
# recall: 1.0
# specificity: 0.9154929577464789
# precision: 0.14285714285714285
# accuracy: 0.9166666666666666
# f1_score: 0.25
# 0 5 25 0
# isolate: c_freundii_067
# recall: nan
# specificity: 0.8333333333333334
# precision: 0.0
# accuracy: 0.8333333333333334
# f1_score: nan
# 11 8 71 4
# isolate: c_freundii_068
# recall: 0.7333333333333333
# specificity: 0.8987341772151899
# precision: 0.5789473684210527
# accuracy: 0.8723404255319149
# f1_score: 0.6470588235294117
# 0 3 59 0
# isolate: c_freundii_069
# recall: nan
# specificity: 0.9516129032258065
# precision: 0.0
# accuracy: 0.9516129032258065
# f1_score: nan
# 0 11 32 0
# isolate: c_freundii_071
# recall: nan
# specificity: 0.7441860465116279
# precision: 0.0
# accuracy: 0.7441860465116279
# f1_score: nan
# 0 0 40 0
# isolate: c_freundii_072
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 0 0 42 0
# isolate: c_freundii_073
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 0 19 127 0
# isolate: c_freundii_074
# recall: nan
# specificity: 0.8698630136986302
# precision: 0.0
# accuracy: 0.8698630136986302
# f1_score: nan
# 0 0 50 0
# isolate: c_freundii_075
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 0 4 47 0
# isolate: c_freundii_076
# recall: nan
# specificity: 0.9215686274509803
# precision: 0.0
# accuracy: 0.9215686274509803
# f1_score: nan
# 0 2 31 0
# isolate: c_freundii_077
# recall: nan
# specificity: 0.9393939393939394
# precision: 0.0
# accuracy: 0.9393939393939394
# f1_score: nan
# 0 1 38 0
# isolate: c_freundii_078
# recall: nan
# specificity: 0.9743589743589743
# precision: 0.0
# accuracy: 0.9743589743589743
# f1_score: nan
# 1 7 101 0
# isolate: c_freundii_079
# recall: 1.0
# specificity: 0.9351851851851852
# precision: 0.125
# accuracy: 0.9357798165137615
# f1_score: 0.2222222222222222
# 28 37 81 0
# isolate: c_freundii_080
# recall: 1.0
# specificity: 0.6864406779661016
# precision: 0.4307692307692308
# accuracy: 0.7465753424657534
# f1_score: 0.6021505376344086
# 0 24 50 0
# isolate: c_freundii_081
# recall: nan
# specificity: 0.6756756756756757
# precision: 0.0
# accuracy: 0.6756756756756757
# f1_score: nan
# 0 0 45 0
# isolate: c_freundii_082
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 1 10 77 0
# isolate: c_freundii_083
# recall: 1.0
# specificity: 0.8850574712643678
# precision: 0.09090909090909091
# accuracy: 0.8863636363636364
# f1_score: 0.16666666666666669
# 5 0 45 2
# isolate: c_freundii_085
# recall: 0.7142857142857143
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9615384615384616
# f1_score: 0.8333333333333333
# 0 0 29 0
# isolate: c_freundii_086
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 0 0 46 0
# isolate: c_freundii_087
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 2 9 106 3
# isolate: c_freundii_090
# recall: 0.4
# specificity: 0.9217391304347826
# precision: 0.18181818181818182
# accuracy: 0.9
# f1_score: 0.25000000000000006
# 0 0 48 0
# isolate: c_freundii_092
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 37 0 51 2
# isolate: c_freundii_093
# recall: 0.9487179487179487
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9777777777777777
# f1_score: 0.9736842105263158
# 0 0 45 0
# isolate: c_freundii_094
# recall: nan
# specificity: 1.0
# precision: nan
# accuracy: 1.0
# f1_score: nan
# 10 11 90 0
# isolate: c_freundii_095
# recall: 1.0
# specificity: 0.8910891089108911
# precision: 0.47619047619047616
# accuracy: 0.9009009009009009
# f1_score: 0.6451612903225806
# 0 9 40 0
# isolate: c_freundii_096
# recall: nan
# specificity: 0.8163265306122449
# precision: 0.0
# accuracy: 0.8163265306122449
# f1_score: nan

# %%
# metrics using all input sequences

for prediction_file in prediction_files:

    if "metrics" in prediction_file:
        continue

    prediction_df = pd.read_csv(prediction_file, index_col=0)

    isolate = "_".join(prediction_file.split("\\")[-1].split("_")[0:-3])

    minimap2_df = pd.read_csv(
        "../data/alignment_files/"
        + species
        + "/"
        + isolate
        + "_minimap_alignment_labelled_ambiguity_cutoff_1.csv",
        index_col=0,
    )

    tp = 0
    fp = 0
    tn = 0
    fn = 0

    for contig_name, row in prediction_df.iterrows():
        try:  # not all sequences in the graph file are also in the assembly fasta, leading to key error
            # if minimap2_df.loc[contig_name,"short_read_contig_length"] <= 1000:
            #    continue
            # if minimap2_df.loc[contig_name,"label"] == "ambiguous":
            #    continue
            if (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tp += 1
            elif (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fp += 1
            elif not (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fn += 1
            elif not (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tn += 1
        except KeyError:
            pass

    print(tp, fp, tn, fn)

    try:
        recall = tp / (tp + fn)  # TP / P = TP / (TP + FN)
    except ZeroDivisionError:
        recall = np.nan
    try:
        specificity = tn / (tn + fp)  # TN / N = TN / (TN + FP)
    except ZeroDivisionError:
        specificity = np.nan
    try:
        precision = tp / (tp + fp)  # TP / (TP + FP)
    except ZeroDivisionError:
        precision = np.nan
    accuracy = (tp + tn) / (
        tp + tn + fp + fn
    )  # T / all = (TP + TN) / (TP + TN + FP + FN)
    try:
        f1_score = 2 * (
            (recall * precision) / (recall + precision)
        )  # harmonic mean of precision and recall
    except ZeroDivisionError:
        f1_score = np.nan

    print("isolate:", isolate)
    print("recall:", recall)
    print("specificity:", specificity)
    print("precision:", precision)
    print("accuracy:", accuracy)
    print("f1_score:", f1_score)

    result_df = pd.DataFrame(
        [[isolate, recall, specificity, precision, accuracy, f1_score, tp, fp, fn, tn]],
        columns=[
            "isolate",
            "recall",
            "specificity",
            "precision",
            "accuracy",
            "f1_score",
            "tp",
            "fp",
            "fn",
            "tn",
        ],
    )

    result_df.to_csv(
        prediction_file[:-4] + "_metrics_all_ambiguous_equal_chromosome.csv",
        index=False,
    )
# Out:
# 57 0 0 0
# isolate: c_freundii_001
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 111 2 33 23
# isolate: c_freundii_002
# recall: 0.8283582089552238
# specificity: 0.9428571428571428
# precision: 0.9823008849557522
# accuracy: 0.8520710059171598
# f1_score: 0.8987854251012145
# 87 7 45 11
# isolate: c_freundii_003
# recall: 0.8877551020408163
# specificity: 0.8653846153846154
# precision: 0.925531914893617
# accuracy: 0.88
# f1_score: 0.90625
# 58 4 18 17
# isolate: c_freundii_004
# recall: 0.7733333333333333
# specificity: 0.8181818181818182
# precision: 0.9354838709677419
# accuracy: 0.7835051546391752
# f1_score: 0.8467153284671532
# 95 0 0 7
# isolate: c_freundii_005
# recall: 0.9313725490196079
# specificity: nan
# precision: 1.0
# accuracy: 0.9313725490196079
# f1_score: 0.9644670050761421
# 124 9 28 16
# isolate: c_freundii_006
# recall: 0.8857142857142857
# specificity: 0.7567567567567568
# precision: 0.9323308270676691
# accuracy: 0.8587570621468926
# f1_score: 0.9084249084249083
# 131 23 22 7
# isolate: c_freundii_007
# recall: 0.9492753623188406
# specificity: 0.4888888888888889
# precision: 0.8506493506493507
# accuracy: 0.8360655737704918
# f1_score: 0.8972602739726028
# 50 0 0 0
# isolate: c_freundii_008
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 39 0 0 1
# isolate: c_freundii_009
# recall: 0.975
# specificity: nan
# precision: 1.0
# accuracy: 0.975
# f1_score: 0.9873417721518987
# 54 0 0 0
# isolate: c_freundii_010
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 79 4 5 5
# isolate: c_freundii_011
# recall: 0.9404761904761905
# specificity: 0.5555555555555556
# precision: 0.9518072289156626
# accuracy: 0.9032258064516129
# f1_score: 0.9461077844311376
# 99 4 4 15
# isolate: c_freundii_012
# recall: 0.868421052631579
# specificity: 0.5
# precision: 0.9611650485436893
# accuracy: 0.8442622950819673
# f1_score: 0.9124423963133641
# 59 5 1 12
# isolate: c_freundii_013
# recall: 0.8309859154929577
# specificity: 0.16666666666666666
# precision: 0.921875
# accuracy: 0.7792207792207793
# f1_score: 0.874074074074074
# 138 7 19 61
# isolate: c_freundii_014
# recall: 0.6934673366834171
# specificity: 0.7307692307692307
# precision: 0.9517241379310345
# accuracy: 0.6977777777777778
# f1_score: 0.8023255813953488
# 73 0 0 2
# isolate: c_freundii_015
# recall: 0.9733333333333334
# specificity: nan
# precision: 1.0
# accuracy: 0.9733333333333334
# f1_score: 0.9864864864864865
# 28 0 1 0
# isolate: c_freundii_016
# recall: 1.0
# specificity: 1.0
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 39 0 0 0
# isolate: c_freundii_017
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 61 1 14 7
# isolate: c_freundii_018
# recall: 0.8970588235294118
# specificity: 0.9333333333333333
# precision: 0.9838709677419355
# accuracy: 0.9036144578313253
# f1_score: 0.9384615384615386
# 69 1 0 0
# isolate: c_freundii_019
# recall: 1.0
# specificity: 0.0
# precision: 0.9857142857142858
# accuracy: 0.9857142857142858
# f1_score: 0.9928057553956835
# 37 0 0 0
# isolate: c_freundii_020
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 111 12 37 19
# isolate: c_freundii_021
# recall: 0.8538461538461538
# specificity: 0.7551020408163265
# precision: 0.9024390243902439
# accuracy: 0.8268156424581006
# f1_score: 0.8774703557312253
# 61 0 6 0
# isolate: c_freundii_022
# recall: 1.0
# specificity: 1.0
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 104 23 13 0
# isolate: c_freundii_023
# recall: 1.0
# specificity: 0.3611111111111111
# precision: 0.8188976377952756
# accuracy: 0.8357142857142857
# f1_score: 0.9004329004329005
# 134 7 4 18
# isolate: c_freundii_024
# recall: 0.881578947368421
# specificity: 0.36363636363636365
# precision: 0.950354609929078
# accuracy: 0.8466257668711656
# f1_score: 0.9146757679180887
# 33 0 11 0
# isolate: c_freundii_025
# recall: 1.0
# specificity: 1.0
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 135 2 34 2
# isolate: c_freundii_026
# recall: 0.9854014598540146
# specificity: 0.9444444444444444
# precision: 0.9854014598540146
# accuracy: 0.976878612716763
# f1_score: 0.9854014598540146
# 29 0 0 0
# isolate: c_freundii_027
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 74 31 80 5
# isolate: c_freundii_030
# recall: 0.9367088607594937
# specificity: 0.7207207207207207
# precision: 0.7047619047619048
# accuracy: 0.8105263157894737
# f1_score: 0.8043478260869565
# 132 18 26 10
# isolate: c_freundii_031
# recall: 0.9295774647887324
# specificity: 0.5909090909090909
# precision: 0.88
# accuracy: 0.8494623655913979
# f1_score: 0.9041095890410958
# 52 0 0 2
# isolate: c_freundii_033
# recall: 0.9629629629629629
# specificity: nan
# precision: 1.0
# accuracy: 0.9629629629629629
# f1_score: 0.9811320754716981
# 50 0 0 0
# isolate: c_freundii_034
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 94 0 0 27
# isolate: c_freundii_035
# recall: 0.7768595041322314
# specificity: nan
# precision: 1.0
# accuracy: 0.7768595041322314
# f1_score: 0.8744186046511627
# 54 0 0 0
# isolate: c_freundii_036
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 89 4 1 7
# isolate: c_freundii_037
# recall: 0.9270833333333334
# specificity: 0.2
# precision: 0.956989247311828
# accuracy: 0.8910891089108911
# f1_score: 0.9417989417989417
# 75 17 41 1
# isolate: c_freundii_038
# recall: 0.9868421052631579
# specificity: 0.7068965517241379
# precision: 0.8152173913043478
# accuracy: 0.8656716417910447
# f1_score: 0.8928571428571429
# 122 9 23 6
# isolate: c_freundii_039
# recall: 0.953125
# specificity: 0.71875
# precision: 0.9312977099236641
# accuracy: 0.90625
# f1_score: 0.9420849420849421
# 121 9 21 11
# isolate: c_freundii_040
# recall: 0.9166666666666666
# specificity: 0.7
# precision: 0.9307692307692308
# accuracy: 0.8765432098765432
# f1_score: 0.9236641221374045
# 85 3 17 17
# isolate: c_freundii_041
# recall: 0.8333333333333334
# specificity: 0.85
# precision: 0.9659090909090909
# accuracy: 0.8360655737704918
# f1_score: 0.8947368421052632
# 79 3 17 23
# isolate: c_freundii_042
# recall: 0.7745098039215687
# specificity: 0.85
# precision: 0.9634146341463414
# accuracy: 0.7868852459016393
# f1_score: 0.8586956521739132
# 128 22 17 13
# isolate: c_freundii_043
# recall: 0.9078014184397163
# specificity: 0.4358974358974359
# precision: 0.8533333333333334
# accuracy: 0.8055555555555556
# f1_score: 0.8797250859106529
# 84 30 79 1
# isolate: c_freundii_044
# recall: 0.9882352941176471
# specificity: 0.7247706422018348
# precision: 0.7368421052631579
# accuracy: 0.8402061855670103
# f1_score: 0.8442211055276382
# 139 21 8 11
# isolate: c_freundii_045
# recall: 0.9266666666666666
# specificity: 0.27586206896551724
# precision: 0.86875
# accuracy: 0.8212290502793296
# f1_score: 0.896774193548387
# 119 8 26 17
# isolate: c_freundii_046
# recall: 0.875
# specificity: 0.7647058823529411
# precision: 0.937007874015748
# accuracy: 0.8529411764705882
# f1_score: 0.9049429657794676
# 52 0 0 3
# isolate: c_freundii_047
# recall: 0.9454545454545454
# specificity: nan
# precision: 1.0
# accuracy: 0.9454545454545454
# f1_score: 0.9719626168224299
# 58 1 24 20
# isolate: c_freundii_048
# recall: 0.7435897435897436
# specificity: 0.96
# precision: 0.9830508474576272
# accuracy: 0.7961165048543689
# f1_score: 0.8467153284671532
# 64 0 0 0
# isolate: c_freundii_049
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 42 0 0 0
# isolate: c_freundii_050
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 44 0 0 0
# isolate: c_freundii_051
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 121 5 21 16
# isolate: c_freundii_052
# recall: 0.8832116788321168
# specificity: 0.8076923076923077
# precision: 0.9603174603174603
# accuracy: 0.8711656441717791
# f1_score: 0.920152091254753
# 58 27 14 4
# isolate: c_freundii_053
# recall: 0.9354838709677419
# specificity: 0.34146341463414637
# precision: 0.6823529411764706
# accuracy: 0.6990291262135923
# f1_score: 0.7891156462585035
# 89 8 29 9
# isolate: c_freundii_054
# recall: 0.9081632653061225
# specificity: 0.7837837837837838
# precision: 0.9175257731958762
# accuracy: 0.8740740740740741
# f1_score: 0.9128205128205128
# 66 0 0 2
# isolate: c_freundii_055
# recall: 0.9705882352941176
# specificity: nan
# precision: 1.0
# accuracy: 0.9705882352941176
# f1_score: 0.9850746268656716
# 64 0 0 1
# isolate: c_freundii_056
# recall: 0.9846153846153847
# specificity: nan
# precision: 1.0
# accuracy: 0.9846153846153847
# f1_score: 0.9922480620155039
# 64 0 0 3
# isolate: c_freundii_057
# recall: 0.9552238805970149
# specificity: nan
# precision: 1.0
# accuracy: 0.9552238805970149
# f1_score: 0.9770992366412213
# 45 0 0 1
# isolate: c_freundii_058
# recall: 0.9782608695652174
# specificity: nan
# precision: 1.0
# accuracy: 0.9782608695652174
# f1_score: 0.989010989010989
# 36 0 0 0
# isolate: c_freundii_059
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 35 0 0 0
# isolate: c_freundii_060
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 33 0 0 0
# isolate: c_freundii_061
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 56 0 0 10
# isolate: c_freundii_062
# recall: 0.8484848484848485
# specificity: nan
# precision: 1.0
# accuracy: 0.8484848484848485
# f1_score: 0.9180327868852458
# 45 0 1 0
# isolate: c_freundii_063
# recall: 1.0
# specificity: 1.0
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 70 6 29 1
# isolate: c_freundii_064
# recall: 0.9859154929577465
# specificity: 0.8285714285714286
# precision: 0.9210526315789473
# accuracy: 0.9339622641509434
# f1_score: 0.9523809523809524
# 76 0 0 0
# isolate: c_freundii_065
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 65 0 1 6
# isolate: c_freundii_066
# recall: 0.9154929577464789
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9166666666666666
# f1_score: 0.9558823529411764
# 27 0 0 3
# isolate: c_freundii_067
# recall: 0.9
# specificity: nan
# precision: 1.0
# accuracy: 0.9
# f1_score: 0.9473684210526316
# 78 6 5 5
# isolate: c_freundii_068
# recall: 0.9397590361445783
# specificity: 0.45454545454545453
# precision: 0.9285714285714286
# accuracy: 0.8829787234042553
# f1_score: 0.9341317365269461
# 59 0 0 3
# isolate: c_freundii_069
# recall: 0.9516129032258065
# specificity: nan
# precision: 1.0
# accuracy: 0.9516129032258065
# f1_score: 0.9752066115702479
# 33 0 0 10
# isolate: c_freundii_071
# recall: 0.7674418604651163
# specificity: nan
# precision: 1.0
# accuracy: 0.7674418604651163
# f1_score: 0.868421052631579
# 40 0 0 0
# isolate: c_freundii_072
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 42 0 0 0
# isolate: c_freundii_073
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 135 0 0 11
# isolate: c_freundii_074
# recall: 0.9246575342465754
# specificity: nan
# precision: 1.0
# accuracy: 0.9246575342465754
# f1_score: 0.9608540925266905
# 50 0 0 0
# isolate: c_freundii_075
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 50 0 0 1
# isolate: c_freundii_076
# recall: 0.9803921568627451
# specificity: nan
# precision: 1.0
# accuracy: 0.9803921568627451
# f1_score: 0.99009900990099
# 32 0 0 1
# isolate: c_freundii_077
# recall: 0.9696969696969697
# specificity: nan
# precision: 1.0
# accuracy: 0.9696969696969697
# f1_score: 0.9846153846153847
# 39 0 0 0
# isolate: c_freundii_078
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 103 0 1 5
# isolate: c_freundii_079
# recall: 0.9537037037037037
# specificity: 1.0
# precision: 1.0
# accuracy: 0.9541284403669725
# f1_score: 0.976303317535545
# 97 2 13 34
# isolate: c_freundii_080
# recall: 0.7404580152671756
# specificity: 0.8666666666666667
# precision: 0.9797979797979798
# accuracy: 0.7534246575342466
# f1_score: 0.8434782608695651
# 53 1 0 20
# isolate: c_freundii_081
# recall: 0.726027397260274
# specificity: 0.0
# precision: 0.9814814814814815
# accuracy: 0.7162162162162162
# f1_score: 0.8346456692913385
# 45 0 0 0
# isolate: c_freundii_082
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 87 0 1 0
# isolate: c_freundii_083
# recall: 1.0
# specificity: 1.0
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 47 0 5 0
# isolate: c_freundii_085
# recall: 1.0
# specificity: 1.0
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 29 0 0 0
# isolate: c_freundii_086
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 46 0 0 0
# isolate: c_freundii_087
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 107 6 2 5
# isolate: c_freundii_090
# recall: 0.9553571428571429
# specificity: 0.25
# precision: 0.9469026548672567
# accuracy: 0.9083333333333333
# f1_score: 0.9511111111111111
# 48 0 0 0
# isolate: c_freundii_092
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 51 2 37 0
# isolate: c_freundii_093
# recall: 1.0
# specificity: 0.9487179487179487
# precision: 0.9622641509433962
# accuracy: 0.9777777777777777
# f1_score: 0.9807692307692307
# 45 0 0 0
# isolate: c_freundii_094
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 97 0 10 4
# isolate: c_freundii_095
# recall: 0.9603960396039604
# specificity: 1.0
# precision: 1.0
# accuracy: 0.963963963963964
# f1_score: 0.9797979797979798
# 43 0 0 6
# isolate: c_freundii_096
# recall: 0.8775510204081632
# specificity: nan
# precision: 1.0
# accuracy: 0.8775510204081632
# f1_score: 0.9347826086956522

# %% [markdown]
# __K. oxytoca__

# %%
species = "k_oxytoca"

# %%
prediction_files = glob("../results/generalized/" + species + "/*.csv")

# %%
# metrics using all input sequences

for prediction_file in prediction_files:

    if "metrics" in prediction_file:
        continue

    prediction_df = pd.read_csv(prediction_file, index_col=0)

    isolate = "_".join(prediction_file.split("\\")[-1].split("_")[0:-3])

    minimap2_df = pd.read_csv(
        "../data/alignment_files/"
        + species
        + "/"
        + isolate
        + "_alignment_labelled_ambiguity_cutoff_1.csv",
        index_col=0,
    )

    tp = 0
    fp = 0
    tn = 0
    fn = 0

    for contig_name, row in prediction_df.iterrows():
        try:  # not all sequences in the graph file are also in the assembly fasta, leading to key error
            # if minimap2_df.loc[contig_name,"short_read_contig_length"] <= 1000:
            #    continue
            # if minimap2_df.loc[contig_name,"label"] == "ambiguous":
            #    continue
            if (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tp += 1
            elif (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fp += 1
            elif not (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fn += 1
            elif not (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tn += 1
        except KeyError:
            pass

    print(tp, fp, tn, fn)

    try:
        recall = tp / (tp + fn)  # TP / P = TP / (TP + FN)
    except ZeroDivisionError:
        recall = np.nan
    specificity = tn / (tn + fp)  # TN / N = TN / (TN + FP)
    try:
        precision = tp / (tp + fp)  # TP / (TP + FP)
    except ZeroDivisionError:
        precision = np.nan
    accuracy = (tp + tn) / (
        tp + tn + fp + fn
    )  # T / all = (TP + TN) / (TP + TN + FP + FN)
    try:
        f1_score = 2 * (
            (recall * precision) / (recall + precision)
        )  # harmonic mean of precision and recall
    except ZeroDivisionError:
        f1_score = np.nan

    print("isolate:", isolate)
    print("recall:", recall)
    print("specificity:", specificity)
    print("precision:", precision)
    print("accuracy:", accuracy)
    print("f1_score:", f1_score)

    result_df = pd.DataFrame(
        [[isolate, recall, specificity, precision, accuracy, f1_score, tp, fp, fn, tn]],
        columns=[
            "isolate",
            "recall",
            "specificity",
            "precision",
            "accuracy",
            "f1_score",
            "tp",
            "fp",
            "fn",
            "tn",
        ],
    )

    result_df.to_csv(
        prediction_file[:-4] + "_metrics_all_ambiguous_equal_plasmid.csv", index=False
    )
# Out:
# 20 53 79 0
# isolate: koxy-SAMN15148173
# recall: 1.0
# specificity: 0.5984848484848485
# precision: 0.273972602739726
# accuracy: 0.6513157894736842
# f1_score: 0.43010752688172044
# 19 26 91 0
# isolate: koxy-SAMN15148174
# recall: 1.0
# specificity: 0.7777777777777778
# precision: 0.4222222222222222
# accuracy: 0.8088235294117647
# f1_score: 0.59375
# 29 28 99 0
# isolate: koxy-SAMN15148287
# recall: 1.0
# specificity: 0.7795275590551181
# precision: 0.5087719298245614
# accuracy: 0.8205128205128205
# f1_score: 0.6744186046511628
# 80 26 81 2
# isolate: koxy-SAMN15148459
# recall: 0.975609756097561
# specificity: 0.7570093457943925
# precision: 0.7547169811320755
# accuracy: 0.8518518518518519
# f1_score: 0.851063829787234
# 100 40 105 0
# isolate: koxy-SAMN15148463
# recall: 1.0
# specificity: 0.7241379310344828
# precision: 0.7142857142857143
# accuracy: 0.8367346938775511
# f1_score: 0.8333333333333333
# 248 22 64 0
# isolate: koxy-SAMN15148522
# recall: 1.0
# specificity: 0.7441860465116279
# precision: 0.9185185185185185
# accuracy: 0.9341317365269461
# f1_score: 0.9575289575289575
# 11 3 74 1
# isolate: koxy-SAMN15148527
# recall: 0.9166666666666666
# specificity: 0.961038961038961
# precision: 0.7857142857142857
# accuracy: 0.9550561797752809
# f1_score: 0.8461538461538461
# 21 12 69 0
# isolate: koxy-SAMN15148529
# recall: 1.0
# specificity: 0.8518518518518519
# precision: 0.6363636363636364
# accuracy: 0.8823529411764706
# f1_score: 0.7777777777777778
# 19 20 64 1
# isolate: koxy-SAMN15148531
# recall: 0.95
# specificity: 0.7619047619047619
# precision: 0.48717948717948717
# accuracy: 0.7980769230769231
# f1_score: 0.6440677966101694
# 49 35 119 0
# isolate: koxy-SAMN15148592
# recall: 1.0
# specificity: 0.7727272727272727
# precision: 0.5833333333333334
# accuracy: 0.8275862068965517
# f1_score: 0.7368421052631579
# 168 75 56 0
# isolate: koxy-SAMN15148604
# recall: 1.0
# specificity: 0.42748091603053434
# precision: 0.691358024691358
# accuracy: 0.7491638795986622
# f1_score: 0.8175182481751825
# 78 16 76 3
# isolate: koxy-SAMN15148609
# recall: 0.9629629629629629
# specificity: 0.8260869565217391
# precision: 0.8297872340425532
# accuracy: 0.8901734104046243
# f1_score: 0.8914285714285713
# 30 73 74 2
# isolate: koxy-SAMN15148636
# recall: 0.9375
# specificity: 0.5034013605442177
# precision: 0.2912621359223301
# accuracy: 0.5810055865921788
# f1_score: 0.4444444444444445
# 2 2 81 7
# isolate: koxy-SAMN15148647
# recall: 0.2222222222222222
# specificity: 0.9759036144578314
# precision: 0.5
# accuracy: 0.9021739130434783
# f1_score: 0.30769230769230765
# 96 32 81 4
# isolate: koxy-SAMN15148651
# recall: 0.96
# specificity: 0.7168141592920354
# precision: 0.75
# accuracy: 0.8309859154929577
# f1_score: 0.8421052631578947
# 41 59 73 0
# isolate: koxy-SAMN15148657
# recall: 1.0
# specificity: 0.553030303030303
# precision: 0.41
# accuracy: 0.6589595375722543
# f1_score: 0.5815602836879432
# 252 34 73 4
# isolate: koxy-SAMN15148669
# recall: 0.984375
# specificity: 0.6822429906542056
# precision: 0.8811188811188811
# accuracy: 0.8953168044077136
# f1_score: 0.9298892988929889
# 44 10 72 2
# isolate: koxy-SAMN15148673
# recall: 0.9565217391304348
# specificity: 0.8780487804878049
# precision: 0.8148148148148148
# accuracy: 0.90625
# f1_score: 0.8800000000000001
# 86 23 58 6
# isolate: koxy-SAMN15148681
# recall: 0.9347826086956522
# specificity: 0.7160493827160493
# precision: 0.7889908256880734
# accuracy: 0.8323699421965318
# f1_score: 0.855721393034826
# 20 36 105 5
# isolate: koxy-SAMN15148716
# recall: 0.8
# specificity: 0.7446808510638298
# precision: 0.35714285714285715
# accuracy: 0.7530120481927711
# f1_score: 0.4938271604938272
# 125 39 127 1
# isolate: koxy-SAMN15148734
# recall: 0.9920634920634921
# specificity: 0.7650602409638554
# precision: 0.7621951219512195
# accuracy: 0.863013698630137
# f1_score: 0.8620689655172414
# 218 24 75 10
# isolate: koxy-SAMN15148741
# recall: 0.956140350877193
# specificity: 0.7575757575757576
# precision: 0.9008264462809917
# accuracy: 0.8960244648318043
# f1_score: 0.927659574468085

# %%
# metrics using all input sequences

for prediction_file in prediction_files:

    if "metrics" in prediction_file:
        continue

    prediction_df = pd.read_csv(prediction_file, index_col=0)

    isolate = "_".join(prediction_file.split("\\")[-1].split("_")[0:-3])

    minimap2_df = pd.read_csv(
        "../data/alignment_files/"
        + species
        + "/"
        + isolate
        + "_alignment_labelled_ambiguity_cutoff_1.csv",
        index_col=0,
    )

    tp = 0
    fp = 0
    tn = 0
    fn = 0

    for contig_name, row in prediction_df.iterrows():
        try:  # not all sequences in the graph file are also in the assembly fasta, leading to key error
            # if minimap2_df.loc[contig_name,"short_read_contig_length"] <= 1000:
            #    continue
            # if minimap2_df.loc[contig_name,"label"] == "ambiguous":
            #    continue
            if (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tp += 1
            elif (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fp += 1
            elif not (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fn += 1
            elif not (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tn += 1
        except KeyError:
            pass

    print(tp, fp, tn, fn)

    try:
        recall = tp / (tp + fn)  # TP / P = TP / (TP + FN)
    except ZeroDivisionError:
        recall = np.nan
    try:
        specificity = tn / (tn + fp)  # TN / N = TN / (TN + FP)
    except ZeroDivisionError:
        specificity = np.nan
    try:
        precision = tp / (tp + fp)  # TP / (TP + FP)
    except ZeroDivisionError:
        precision = np.nan
    accuracy = (tp + tn) / (
        tp + tn + fp + fn
    )  # T / all = (TP + TN) / (TP + TN + FP + FN)
    try:
        f1_score = 2 * (
            (recall * precision) / (recall + precision)
        )  # harmonic mean of precision and recall
    except ZeroDivisionError:
        f1_score = np.nan

    print("isolate:", isolate)
    print("recall:", recall)
    print("specificity:", specificity)
    print("precision:", precision)
    print("accuracy:", accuracy)
    print("f1_score:", f1_score)

    result_df = pd.DataFrame(
        [[isolate, recall, specificity, precision, accuracy, f1_score, tp, fp, fn, tn]],
        columns=[
            "isolate",
            "recall",
            "specificity",
            "precision",
            "accuracy",
            "f1_score",
            "tp",
            "fp",
            "fn",
            "tn",
        ],
    )

    result_df.to_csv(
        prediction_file[:-4] + "_metrics_all_ambiguous_equal_chromosome.csv",
        index=False,
    )
# Out:
# 94 2 18 38
# isolate: koxy-SAMN15148173
# recall: 0.7121212121212122
# specificity: 0.9
# precision: 0.9791666666666666
# accuracy: 0.7368421052631579
# f1_score: 0.8245614035087719
# 103 3 16 14
# isolate: koxy-SAMN15148174
# recall: 0.8803418803418803
# specificity: 0.8421052631578947
# precision: 0.9716981132075472
# accuracy: 0.875
# f1_score: 0.9237668161434976
# 104 1 27 24
# isolate: koxy-SAMN15148287
# recall: 0.8125
# specificity: 0.9642857142857143
# precision: 0.9904761904761905
# accuracy: 0.8397435897435898
# f1_score: 0.8927038626609443
# 102 7 68 12
# isolate: koxy-SAMN15148459
# recall: 0.8947368421052632
# specificity: 0.9066666666666666
# precision: 0.9357798165137615
# accuracy: 0.8994708994708994
# f1_score: 0.9147982062780269
# 132 11 67 35
# isolate: koxy-SAMN15148463
# recall: 0.7904191616766467
# specificity: 0.8589743589743589
# precision: 0.9230769230769231
# accuracy: 0.8122448979591836
# f1_score: 0.8516129032258065
# 83 5 225 21
# isolate: koxy-SAMN15148522
# recall: 0.7980769230769231
# specificity: 0.9782608695652174
# precision: 0.9431818181818182
# accuracy: 0.9221556886227545
# f1_score: 0.8645833333333335
# 77 4 6 2
# isolate: koxy-SAMN15148527
# recall: 0.9746835443037974
# specificity: 0.6
# precision: 0.9506172839506173
# accuracy: 0.9325842696629213
# f1_score: 0.9625
# 75 0 16 11
# isolate: koxy-SAMN15148529
# recall: 0.872093023255814
# specificity: 1.0
# precision: 1.0
# accuracy: 0.8921568627450981
# f1_score: 0.9316770186335404
# 78 3 12 11
# isolate: koxy-SAMN15148531
# recall: 0.8764044943820225
# specificity: 0.8
# precision: 0.9629629629629629
# accuracy: 0.8653846153846154
# f1_score: 0.9176470588235294
# 139 5 36 23
# isolate: koxy-SAMN15148592
# recall: 0.8580246913580247
# specificity: 0.8780487804878049
# precision: 0.9652777777777778
# accuracy: 0.8620689655172413
# f1_score: 0.9084967320261438
# 102 5 138 54
# isolate: koxy-SAMN15148604
# recall: 0.6538461538461539
# specificity: 0.965034965034965
# precision: 0.9532710280373832
# accuracy: 0.802675585284281
# f1_score: 0.7756653992395437
# 99 14 47 13
# isolate: koxy-SAMN15148609
# recall: 0.8839285714285714
# specificity: 0.7704918032786885
# precision: 0.8761061946902655
# accuracy: 0.8439306358381503
# f1_score: 0.88
# 104 4 18 53
# isolate: koxy-SAMN15148636
# recall: 0.6624203821656051
# specificity: 0.8181818181818182
# precision: 0.9629629629629629
# accuracy: 0.6815642458100558
# f1_score: 0.7849056603773584
# 85 5 1 1
# isolate: koxy-SAMN15148647
# recall: 0.9883720930232558
# specificity: 0.16666666666666666
# precision: 0.9444444444444444
# accuracy: 0.9347826086956522
# f1_score: 0.9659090909090908
# 106 8 70 29
# isolate: koxy-SAMN15148651
# recall: 0.7851851851851852
# specificity: 0.8974358974358975
# precision: 0.9298245614035088
# accuracy: 0.8262910798122066
# f1_score: 0.8514056224899599
# 100 0 35 38
# isolate: koxy-SAMN15148657
# recall: 0.7246376811594203
# specificity: 1.0
# precision: 1.0
# accuracy: 0.7803468208092486
# f1_score: 0.8403361344537814
# 102 18 209 34
# isolate: koxy-SAMN15148669
# recall: 0.75
# specificity: 0.920704845814978
# precision: 0.85
# accuracy: 0.8567493112947658
# f1_score: 0.7968749999999999
# 84 5 31 8
# isolate: koxy-SAMN15148673
# recall: 0.9130434782608695
# specificity: 0.8611111111111112
# precision: 0.9438202247191011
# accuracy: 0.8984375
# f1_score: 0.9281767955801105
# 77 19 50 27
# isolate: koxy-SAMN15148681
# recall: 0.7403846153846154
# specificity: 0.7246376811594203
# precision: 0.8020833333333334
# accuracy: 0.7341040462427746
# f1_score: 0.77
# 131 2 16 17
# isolate: koxy-SAMN15148716
# recall: 0.8851351351351351
# specificity: 0.8888888888888888
# precision: 0.9849624060150376
# accuracy: 0.8855421686746988
# f1_score: 0.9323843416370107
# 155 4 89 44
# isolate: koxy-SAMN15148734
# recall: 0.7788944723618091
# specificity: 0.956989247311828
# precision: 0.9748427672955975
# accuracy: 0.8356164383561644
# f1_score: 0.8659217877094972
# 105 60 142 20
# isolate: koxy-SAMN15148741
# recall: 0.84
# specificity: 0.7029702970297029
# precision: 0.6363636363636364
# accuracy: 0.7553516819571865
# f1_score: 0.7241379310344828

# %% [markdown]
# __B. megaterium__

# %%
species = "b_megaterium"

# %%
prediction_files = glob("../results/generalized/" + species + "/*.csv")

# %%
# metrics using all input sequences

for prediction_file in prediction_files:

    if "metrics" in prediction_file:
        continue

    prediction_df = pd.read_csv(prediction_file, index_col=0)

    isolate = "_".join(prediction_file.split("\\")[-1].split("_")[0:-3])

    minimap2_df = pd.read_csv(
        "../data/alignment_files/"
        + species
        + "/"
        + isolate
        + "_alignment_labelled_ambiguity_cutoff_1.csv",
        index_col=0,
    )

    tp = 0
    fp = 0
    tn = 0
    fn = 0

    for contig_name, row in prediction_df.iterrows():
        try:  # not all sequences in the graph file are also in the assembly fasta, leading to key error
            # if minimap2_df.loc[contig_name,"short_read_contig_length"] <= 1000:
            #    continue
            # if minimap2_df.loc[contig_name,"label"] == "ambiguous":
            #    continue
            if (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tp += 1
            elif (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fp += 1
            elif not (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fn += 1
            elif not (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tn += 1
        except KeyError:
            pass

    print(tp, fp, tn, fn)

    try:
        recall = tp / (tp + fn)  # TP / P = TP / (TP + FN)
    except ZeroDivisionError:
        recall = np.nan
    specificity = tn / (tn + fp)  # TN / N = TN / (TN + FP)
    try:
        precision = tp / (tp + fp)  # TP / (TP + FP)
    except ZeroDivisionError:
        precision = np.nan
    accuracy = (tp + tn) / (
        tp + tn + fp + fn
    )  # T / all = (TP + TN) / (TP + TN + FP + FN)
    try:
        f1_score = 2 * (
            (recall * precision) / (recall + precision)
        )  # harmonic mean of precision and recall
    except ZeroDivisionError:
        f1_score = np.nan

    print("isolate:", isolate)
    print("recall:", recall)
    print("specificity:", specificity)
    print("precision:", precision)
    print("accuracy:", accuracy)
    print("f1_score:", f1_score)

    result_df = pd.DataFrame(
        [[isolate, recall, specificity, precision, accuracy, f1_score, tp, fp, fn, tn]],
        columns=[
            "isolate",
            "recall",
            "specificity",
            "precision",
            "accuracy",
            "f1_score",
            "tp",
            "fp",
            "fn",
            "tn",
        ],
    )

    result_df.to_csv(
        prediction_file[:-4] + "_metrics_all_ambiguous_equal_plasmid.csv", index=False
    )
# Out:
# 96 14 44 6
# isolate: pmeg-SAMN16083678
# recall: 0.9411764705882353
# specificity: 0.7586206896551724
# precision: 0.8727272727272727
# accuracy: 0.875
# f1_score: 0.9056603773584905
# 89 6 42 11
# isolate: pmeg-SAMN16083679
# recall: 0.89
# specificity: 0.875
# precision: 0.9368421052631579
# accuracy: 0.8851351351351351
# f1_score: 0.9128205128205129

# %%
# metrics using all input sequences

for prediction_file in prediction_files:

    if "metrics" in prediction_file:
        continue

    prediction_df = pd.read_csv(prediction_file, index_col=0)

    isolate = "_".join(prediction_file.split("\\")[-1].split("_")[0:-3])

    minimap2_df = pd.read_csv(
        "../data/alignment_files/"
        + species
        + "/"
        + isolate
        + "_alignment_labelled_ambiguity_cutoff_1.csv",
        index_col=0,
    )

    tp = 0
    fp = 0
    tn = 0
    fn = 0

    for contig_name, row in prediction_df.iterrows():
        try:  # not all sequences in the graph file are also in the assembly fasta, leading to key error
            # if minimap2_df.loc[contig_name,"short_read_contig_length"] <= 1000:
            #    continue
            # if minimap2_df.loc[contig_name,"label"] == "ambiguous":
            #    continue
            if (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tp += 1
            elif (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fp += 1
            elif not (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fn += 1
            elif not (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tn += 1
        except KeyError:
            pass

    print(tp, fp, tn, fn)

    try:
        recall = tp / (tp + fn)  # TP / P = TP / (TP + FN)
    except ZeroDivisionError:
        recall = np.nan
    try:
        specificity = tn / (tn + fp)  # TN / N = TN / (TN + FP)
    except ZeroDivisionError:
        specificity = np.nan
    try:
        precision = tp / (tp + fp)  # TP / (TP + FP)
    except ZeroDivisionError:
        precision = np.nan
    accuracy = (tp + tn) / (
        tp + tn + fp + fn
    )  # T / all = (TP + TN) / (TP + TN + FP + FN)
    try:
        f1_score = 2 * (
            (recall * precision) / (recall + precision)
        )  # harmonic mean of precision and recall
    except ZeroDivisionError:
        f1_score = np.nan

    print("isolate:", isolate)
    print("recall:", recall)
    print("specificity:", specificity)
    print("precision:", precision)
    print("accuracy:", accuracy)
    print("f1_score:", f1_score)

    result_df = pd.DataFrame(
        [[isolate, recall, specificity, precision, accuracy, f1_score, tp, fp, fn, tn]],
        columns=[
            "isolate",
            "recall",
            "specificity",
            "precision",
            "accuracy",
            "f1_score",
            "tp",
            "fp",
            "fn",
            "tn",
        ],
    )

    result_df.to_csv(
        prediction_file[:-4] + "_metrics_all_ambiguous_equal_chromosome.csv",
        index=False,
    )
# Out:
# 67 12 58 23
# isolate: pmeg-SAMN16083678
# recall: 0.7444444444444445
# specificity: 0.8285714285714286
# precision: 0.8481012658227848
# accuracy: 0.78125
# f1_score: 0.7928994082840237
# 53 9 82 4
# isolate: pmeg-SAMN16083679
# recall: 0.9298245614035088
# specificity: 0.9010989010989011
# precision: 0.8548387096774194
# accuracy: 0.9121621621621622
# f1_score: 0.8907563025210085

# %% [markdown]
# __S. pseudintermedius__

# %%
species = "s_pseudintermedius"

# %%
prediction_files = glob("../results/generalized/" + species + "/*.csv")

# %%
# metrics using all input sequences

for prediction_file in prediction_files:

    if "metrics" in prediction_file:
        continue

    prediction_df = pd.read_csv(prediction_file, index_col=0)

    isolate = "_".join(prediction_file.split("\\")[-1].split("_")[0:-3])

    minimap2_df = pd.read_csv(
        "../data/alignment_files/"
        + species
        + "/"
        + isolate
        + "_alignment_labelled_ambiguity_cutoff_1.csv",
        index_col=0,
    )

    tp = 0
    fp = 0
    tn = 0
    fn = 0

    for contig_name, row in prediction_df.iterrows():
        try:  # not all sequences in the graph file are also in the assembly fasta, leading to key error
            # if minimap2_df.loc[contig_name,"short_read_contig_length"] <= 1000:
            #    continue
            # if minimap2_df.loc[contig_name,"label"] == "ambiguous":
            #    continue
            if (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tp += 1
            elif (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fp += 1
            elif not (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fn += 1
            elif not (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tn += 1
        except KeyError:
            pass

    print(tp, fp, tn, fn)

    try:
        recall = tp / (tp + fn)  # TP / P = TP / (TP + FN)
    except ZeroDivisionError:
        recall = np.nan
    specificity = tn / (tn + fp)  # TN / N = TN / (TN + FP)
    try:
        precision = tp / (tp + fp)  # TP / (TP + FP)
    except ZeroDivisionError:
        precision = np.nan
    accuracy = (tp + tn) / (
        tp + tn + fp + fn
    )  # T / all = (TP + TN) / (TP + TN + FP + FN)
    try:
        f1_score = 2 * (
            (recall * precision) / (recall + precision)
        )  # harmonic mean of precision and recall
    except ZeroDivisionError:
        f1_score = np.nan

    print("isolate:", isolate)
    print("recall:", recall)
    print("specificity:", specificity)
    print("precision:", precision)
    print("accuracy:", accuracy)
    print("f1_score:", f1_score)

    result_df = pd.DataFrame(
        [[isolate, recall, specificity, precision, accuracy, f1_score, tp, fp, fn, tn]],
        columns=[
            "isolate",
            "recall",
            "specificity",
            "precision",
            "accuracy",
            "f1_score",
            "tp",
            "fp",
            "fn",
            "tn",
        ],
    )

    result_df.to_csv(
        prediction_file[:-4] + "_metrics_all_ambiguous_equal_plasmid.csv", index=False
    )
# Out:
# 0 7 51 0
# isolate: spse-SAMN10880482
# recall: nan
# specificity: 0.8793103448275862
# precision: 0.0
# accuracy: 0.8793103448275862
# f1_score: nan
# 0 11 37 0
# isolate: spse-SAMN10880484
# recall: nan
# specificity: 0.7708333333333334
# precision: 0.0
# accuracy: 0.7708333333333334
# f1_score: nan
# 0 17 36 7
# isolate: spse-SAMN10880486
# recall: 0.0
# specificity: 0.6792452830188679
# precision: 0.0
# accuracy: 0.6
# f1_score: nan

# %%
# metrics using all input sequences

for prediction_file in prediction_files:

    if "metrics" in prediction_file:
        continue

    prediction_df = pd.read_csv(prediction_file, index_col=0)

    isolate = "_".join(prediction_file.split("\\")[-1].split("_")[0:-3])

    minimap2_df = pd.read_csv(
        "../data/alignment_files/"
        + species
        + "/"
        + isolate
        + "_alignment_labelled_ambiguity_cutoff_1.csv",
        index_col=0,
    )

    tp = 0
    fp = 0
    tn = 0
    fn = 0

    for contig_name, row in prediction_df.iterrows():
        try:  # not all sequences in the graph file are also in the assembly fasta, leading to key error
            # if minimap2_df.loc[contig_name,"short_read_contig_length"] <= 1000:
            #    continue
            # if minimap2_df.loc[contig_name,"label"] == "ambiguous":
            #    continue
            if (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tp += 1
            elif (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fp += 1
            elif not (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fn += 1
            elif not (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tn += 1
        except KeyError:
            pass

    print(tp, fp, tn, fn)

    try:
        recall = tp / (tp + fn)  # TP / P = TP / (TP + FN)
    except ZeroDivisionError:
        recall = np.nan
    try:
        specificity = tn / (tn + fp)  # TN / N = TN / (TN + FP)
    except ZeroDivisionError:
        specificity = np.nan
    try:
        precision = tp / (tp + fp)  # TP / (TP + FP)
    except ZeroDivisionError:
        precision = np.nan
    accuracy = (tp + tn) / (
        tp + tn + fp + fn
    )  # T / all = (TP + TN) / (TP + TN + FP + FN)
    try:
        f1_score = 2 * (
            (recall * precision) / (recall + precision)
        )  # harmonic mean of precision and recall
    except ZeroDivisionError:
        f1_score = np.nan

    print("isolate:", isolate)
    print("recall:", recall)
    print("specificity:", specificity)
    print("precision:", precision)
    print("accuracy:", accuracy)
    print("f1_score:", f1_score)

    result_df = pd.DataFrame(
        [[isolate, recall, specificity, precision, accuracy, f1_score, tp, fp, fn, tn]],
        columns=[
            "isolate",
            "recall",
            "specificity",
            "precision",
            "accuracy",
            "f1_score",
            "tp",
            "fp",
            "fn",
            "tn",
        ],
    )

    result_df.to_csv(
        prediction_file[:-4] + "_metrics_all_ambiguous_equal_chromosome.csv",
        index=False,
    )
# Out:
# 58 0 0 0
# isolate: spse-SAMN10880482
# recall: 1.0
# specificity: nan
# precision: 1.0
# accuracy: 1.0
# f1_score: 1.0
# 42 0 0 6
# isolate: spse-SAMN10880484
# recall: 0.875
# specificity: nan
# precision: 1.0
# accuracy: 0.875
# f1_score: 0.9333333333333333
# 47 5 0 8
# isolate: spse-SAMN10880486
# recall: 0.8545454545454545
# specificity: 0.0
# precision: 0.9038461538461539
# accuracy: 0.7833333333333333
# f1_score: 0.8785046728971962

# %% [markdown]
# __V. parahaemolyticus__

# %%
species = "v_parahaemolyticus"

# %%
prediction_files = glob("../results/generalized/" + species + "/*.csv")

# %%
# metrics using all input sequences

for prediction_file in prediction_files:

    if "metrics" in prediction_file:
        continue

    prediction_df = pd.read_csv(prediction_file, index_col=0)

    isolate = "_".join(prediction_file.split("\\")[-1].split("_")[0:-3])

    minimap2_df = pd.read_csv(
        "../data/alignment_files/"
        + species
        + "/"
        + isolate
        + "_alignment_labelled_ambiguity_cutoff_1.csv",
        index_col=0,
    )

    tp = 0
    fp = 0
    tn = 0
    fn = 0

    for contig_name, row in prediction_df.iterrows():
        try:  # not all sequences in the graph file are also in the assembly fasta, leading to key error
            # if minimap2_df.loc[contig_name,"short_read_contig_length"] <= 1000:
            #    continue
            # if minimap2_df.loc[contig_name,"label"] == "ambiguous":
            #    continue
            if (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tp += 1
            elif (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fp += 1
            elif not (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fn += 1
            elif not (
                row["predicted_label"] == "Plasmid"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "plasmid"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tn += 1
        except KeyError:
            pass

    print(tp, fp, tn, fn)

    try:
        recall = tp / (tp + fn)  # TP / P = TP / (TP + FN)
    except ZeroDivisionError:
        recall = np.nan
    specificity = tn / (tn + fp)  # TN / N = TN / (TN + FP)
    try:
        precision = tp / (tp + fp)  # TP / (TP + FP)
    except ZeroDivisionError:
        precision = np.nan
    accuracy = (tp + tn) / (
        tp + tn + fp + fn
    )  # T / all = (TP + TN) / (TP + TN + FP + FN)
    try:
        f1_score = 2 * (
            (recall * precision) / (recall + precision)
        )  # harmonic mean of precision and recall
    except ZeroDivisionError:
        f1_score = np.nan

    print("isolate:", isolate)
    print("recall:", recall)
    print("specificity:", specificity)
    print("precision:", precision)
    print("accuracy:", accuracy)
    print("f1_score:", f1_score)

    result_df = pd.DataFrame(
        [[isolate, recall, specificity, precision, accuracy, f1_score, tp, fp, fn, tn]],
        columns=[
            "isolate",
            "recall",
            "specificity",
            "precision",
            "accuracy",
            "f1_score",
            "tp",
            "fp",
            "fn",
            "tn",
        ],
    )

    result_df.to_csv(
        prediction_file[:-4] + "_metrics_all_ambiguous_equal_plasmid.csv", index=False
    )
# Out:
# 11 33 24 0
# isolate: vpar-SAMEA5540085
# recall: 1.0
# specificity: 0.42105263157894735
# precision: 0.25
# accuracy: 0.5147058823529411
# f1_score: 0.4
# 0 31 98 0
# isolate: vpar-SAMEA5540086
# recall: nan
# specificity: 0.7596899224806202
# precision: 0.0
# accuracy: 0.7596899224806202
# f1_score: nan
# 5 30 65 0
# isolate: vpar-SAMEA5540087
# recall: 1.0
# specificity: 0.6842105263157895
# precision: 0.14285714285714285
# accuracy: 0.7
# f1_score: 0.25

# %%
# metrics using all input sequences

for prediction_file in prediction_files:

    if "metrics" in prediction_file:
        continue

    prediction_df = pd.read_csv(prediction_file, index_col=0)

    isolate = "_".join(prediction_file.split("\\")[-1].split("_")[0:-3])

    minimap2_df = pd.read_csv(
        "../data/alignment_files/"
        + species
        + "/"
        + isolate
        + "_alignment_labelled_ambiguity_cutoff_1.csv",
        index_col=0,
    )

    tp = 0
    fp = 0
    tn = 0
    fn = 0

    for contig_name, row in prediction_df.iterrows():
        try:  # not all sequences in the graph file are also in the assembly fasta, leading to key error
            # if minimap2_df.loc[contig_name,"short_read_contig_length"] <= 1000:
            #    continue
            # if minimap2_df.loc[contig_name,"label"] == "ambiguous":
            #    continue
            if (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tp += 1
            elif (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fp += 1
            elif not (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                fn += 1
            elif not (
                row["predicted_label"] == "Chromosome"
                or row["predicted_label"] == "Ambiguous"
            ) and not (
                minimap2_df.loc[contig_name, "label"] == "chromosome"
                or minimap2_df.loc[contig_name, "label"] == "ambiguous"
            ):
                tn += 1
        except KeyError:
            pass

    print(tp, fp, tn, fn)

    try:
        recall = tp / (tp + fn)  # TP / P = TP / (TP + FN)
    except ZeroDivisionError:
        recall = np.nan
    try:
        specificity = tn / (tn + fp)  # TN / N = TN / (TN + FP)
    except ZeroDivisionError:
        specificity = np.nan
    try:
        precision = tp / (tp + fp)  # TP / (TP + FP)
    except ZeroDivisionError:
        precision = np.nan
    accuracy = (tp + tn) / (
        tp + tn + fp + fn
    )  # T / all = (TP + TN) / (TP + TN + FP + FN)
    try:
        f1_score = 2 * (
            (recall * precision) / (recall + precision)
        )  # harmonic mean of precision and recall
    except ZeroDivisionError:
        f1_score = np.nan

    print("isolate:", isolate)
    print("recall:", recall)
    print("specificity:", specificity)
    print("precision:", precision)
    print("accuracy:", accuracy)
    print("f1_score:", f1_score)

    result_df = pd.DataFrame(
        [[isolate, recall, specificity, precision, accuracy, f1_score, tp, fp, fn, tn]],
        columns=[
            "isolate",
            "recall",
            "specificity",
            "precision",
            "accuracy",
            "f1_score",
            "tp",
            "fp",
            "fn",
            "tn",
        ],
    )

    result_df.to_csv(
        prediction_file[:-4] + "_metrics_all_ambiguous_equal_chromosome.csv",
        index=False,
    )
# Out:
# 40 3 2 23
# isolate: vpar-SAMEA5540085
# recall: 0.6349206349206349
# specificity: 0.4
# precision: 0.9302325581395349
# accuracy: 0.6176470588235294
# f1_score: 0.7547169811320754
# 116 0 0 13
# isolate: vpar-SAMEA5540086
# recall: 0.8992248062015504
# specificity: nan
# precision: 1.0
# accuracy: 0.8992248062015504
# f1_score: 0.9469387755102041
# 77 0 2 21
# isolate: vpar-SAMEA5540087
# recall: 0.7857142857142857
# specificity: 1.0
# precision: 1.0
# accuracy: 0.79
# f1_score: 0.88
